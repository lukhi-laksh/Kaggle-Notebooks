# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download the combined global gender data Dataset](https://www.kaggle.com/datasets/hammadfarooq470/global-gender-equality-rankings-2023/data)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('combined_global_gender_data_20251123.csv')

# %% [markdown]
# ### Frist Five Row

# %%
df.head()
# Out:
#   Scraped_Date  Data_Year      Country ISO3  Year  \
# 0   2025-11-23       2023  Afghanistan  AFG  2023
# 1   2025-11-23       2023       Africa  NaN  2023
# 2   2025-11-23       2023      Albania  ALB  2023
# 3   2025-11-23       2023      Algeria  DZA  2023
# 4   2025-11-23       2023       Angola  AGO  2023
#
#    Gender Inequality Index (GII) (Gender Inequality Index)
# 0                                            0.66100
# 1                                            0.53045
# 2                                            0.10700
# 3                                            0.44300
# 4                                            0.51500

# %% [markdown]
# ### Last Five Row

# %%
df.tail()
# Out:
#     Scraped_Date  Data_Year   Country      ISO3  Year  \
# 188   2025-11-23       2023   Vietnam       VNM  2023
# 189   2025-11-23       2023     World  OWID_WRL  2023
# 190   2025-11-23       2023     Yemen       YEM  2023
# 191   2025-11-23       2023    Zambia       ZMB  2023
# 192   2025-11-23       2023  Zimbabwe       ZWE  2023
#
#      Gender Inequality Index (GII) (Gender Inequality Index)
# 188                                              0.299
# 189                                              0.455
# 190                                              0.838
# 191                                              0.524
# 192                                              0.519

# %% [markdown]
# ### Shape of our dataset

# %%
df.shape
# Out:
# (193, 6)

# %% [markdown]
# ### List out all columns

# %%
df.columns
# Out:
# Index(['Scraped_Date', 'Data_Year', 'Country', 'ISO3', 'Year',
#        'Gender Inequality Index (GII) (Gender Inequality Index)'],
#       dtype='object')

# %% [markdown]
# ### Datatype of each columns

# %%
df.dtypes
# Out:
# Scraped_Date                                                object
# Data_Year                                                    int64
# Country                                                     object
# ISO3                                                        object
# Year                                                         int64
# Gender Inequality Index (GII) (Gender Inequality Index)    float64
# dtype: object

# %% [markdown]
# ### Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Scraped_Date                                             193 non-null    object
#  1   Data_Year                                                193 non-null    int64
#  2   Country                                                  193 non-null    object
#  3   ISO3                                                     173 non-null    object
#  4   Year                                                     193 non-null    int64
#  5   Gender Inequality Index (GII) (Gender Inequality Index)  193 non-null    float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 9.2+ KB

# %% [markdown]
# ### Check Null Value

# %%
df.isnull().sum()
# Out:
# Scraped_Date                                                0
# Data_Year                                                   0
# Country                                                     0
# ISO3                                                       20
# Year                                                        0
# Gender Inequality Index (GII) (Gender Inequality Index)     0
# dtype: int64

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1
