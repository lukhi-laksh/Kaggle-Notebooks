# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download The Global EV Adaption Dataset](https://www.kaggle.com/datasets/aiexplorer77/from-fuel-to-electric-the-ev-transition-dataset)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# /kaggle/input/datasets/aiexplorer77/from-fuel-to-electric-the-ev-transition-dataset/global_ev_adoption_behavior_2026.csv

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('global_ev_adoption_behavior_2026.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
df.head()
# Out:
#    age  annual_income education_level city_type  daily_commute_km  \
# 0   56        23019.0     High School  Suburban              39.8
# 1   46        26440.0     High School  Suburban              34.6
# 2   46        57167.0             PhD  Suburban              30.5
# 3   23        15841.0          Master  Suburban              44.6
# 4   50        51571.0          Master     Urban              52.4
#
#    weekly_travel_distance_km current_vehicle_type  vehicle_age_years  \
# 0                      205.7            Hatchback                6.1
# 1                      218.4                Sedan                4.4
# 2                      177.7                Sedan                0.4
# 3                      325.9                  SUV                0.0
# 4                      281.0                  SUV                5.2
#
#    fuel_expense_per_month  charging_station_accessibility  ...  \
# 0                   317.1                             3.9  ...
# ...

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#        age  annual_income education_level city_type  daily_commute_km  \
# 49995   27        26296.0        Bachelor     Urban              37.4
# 49996   39        35476.0          Master  Suburban              30.5
# 49997   30        20862.0          Master  Suburban              37.5
# 49998   68        14694.0        Bachelor     Rural              40.3
# 49999   48        28828.0        Bachelor  Suburban              28.5
#
#        weekly_travel_distance_km current_vehicle_type  vehicle_age_years  \
# 49995                      211.4                Sedan                0.0
# 49996                      158.3                Sedan                2.8
# 49997                      295.2                Sedan                0.0
# 49998                      256.5                Sedan                6.0
# 49999                      192.6                Sedan                2.5
#
#        fuel_expense_per_month  charging_station_accessibility  ...  \
# ...

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (50000, 23)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['age', 'annual_income', 'education_level', 'city_type',
#        'daily_commute_km', 'weekly_travel_distance_km', 'current_vehicle_type',
#        'vehicle_age_years', 'fuel_expense_per_month',
#        'charging_station_accessibility', 'nearest_charging_station_km',
#        'home_charging_available', 'electricity_cost_per_kwh',
#        'environmental_awareness_score', 'government_incentive_awareness',
#        'technology_affinity_score', 'range_anxiety_score',
#        'battery_replacement_concern', 'ev_knowledge_score',
#        'previous_ev_experience', 'ev_adoption_likelihood',
#        'monthly_energy_consumption_kwh', 'monthly_charging_cost'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# age                                 int64
# annual_income                     float64
# education_level                    object
# city_type                          object
# daily_commute_km                  float64
# weekly_travel_distance_km         float64
# current_vehicle_type               object
# vehicle_age_years                 float64
# fuel_expense_per_month            float64
# charging_station_accessibility    float64
# nearest_charging_station_km       float64
# home_charging_available             int64
# electricity_cost_per_kwh          float64
# environmental_awareness_score     float64
# government_incentive_awareness    float64
# technology_affinity_score         float64
# range_anxiety_score               float64
# battery_replacement_concern       float64
# ev_knowledge_score                float64
# previous_ev_experience              int64
# ev_adoption_likelihood             object
# monthly_energy_consumption_kwh    float64
# ...

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             50000 non-null  int64
#  1   annual_income                   50000 non-null  float64
#  2   education_level                 49500 non-null  object
#  3   city_type                       50000 non-null  object
#  4   daily_commute_km                50000 non-null  float64
#  5   weekly_travel_distance_km       50000 non-null  float64
#  6   current_vehicle_type            50000 non-null  object
#  7   vehicle_age_years               50000 non-null  float64
#  8   fuel_expense_per_month          50000 non-null  float64
#  9   charging_station_accessibility  49500 non-null  float64
#  10  nearest_charging_station_km     50000 non-null  float64
#  11  home_charging_available         50000 non-null  int64
# ...

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# age                                 0
# annual_income                       0
# education_level                   500
# city_type                           0
# daily_commute_km                    0
# weekly_travel_distance_km           0
# current_vehicle_type                0
# vehicle_age_years                   0
# fuel_expense_per_month              0
# charging_station_accessibility    500
# nearest_charging_station_km         0
# home_charging_available             0
# electricity_cost_per_kwh            0
# environmental_awareness_score       0
# government_incentive_awareness      0
# technology_affinity_score           0
# range_anxiety_score                 0
# battery_replacement_concern         0
# ev_knowledge_score                500
# previous_ev_experience              0
# ev_adoption_likelihood              0
# monthly_energy_consumption_kwh      0
# monthly_charging_cost               0
# dtype: int64

# %% [markdown]
# ## Drop Null Features

# %%
df.drop(columns=['education_level', 'charging_station_accessibility', 'ev_knowledge_score'], inplace=True)

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#                 age  annual_income  daily_commute_km  \
# count  50000.000000   50000.000000      50000.000000
# mean      44.996080   44311.869380         35.169358
# std       14.110844   26109.170784         14.736042
# min       21.000000    5104.000000          5.000000
# 25%       33.000000   25617.750000         25.000000
# 50%       45.000000   37891.000000         35.100000
# 75%       57.000000   56051.250000         45.200000
# max       69.000000  250000.000000         97.900000
#
#        weekly_travel_distance_km  vehicle_age_years  fuel_expense_per_month  \
# count               50000.000000       50000.000000            50000.000000
# mean                  228.727200           6.012842              295.169608
# std                   101.147254           2.947132              130.178552
# min                    25.000000           0.000000              -99.700000
# 25%                   157.700000           3.900000              205.200000
# ...

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(data=df, x='age', hue='ev_adoption_likelihood', kde=True, multiple='stack')
plt.title(f'{plot_no}. Age Distribution Across EV Adoption Likelihood Levels')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='ev_adoption_likelihood', y='annual_income', order=['Low', 'Medium', 'High'])
plt.title(f'{plot_no}. Annual Income Differences by EV Adoption Likelihood')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='city_type', hue='ev_adoption_likelihood', hue_order=['Low', 'Medium', 'High'])
plt.title(f'{plot_no}. EV Adoption Likelihood Across City Types')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.violinplot(data=df, x='ev_adoption_likelihood', y='daily_commute_km', order=['Low', 'Medium', 'High'], inner='quartile')
plt.title(f'{plot_no}. Daily Commute Patterns by EV Adoption Likelihood')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='ev_adoption_likelihood', y='weekly_travel_distance_km', order=['Low', 'Medium', 'High'])
plt.title(f'{plot_no}. Weekly Travel Distance and EV Adoption Interest')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='daily_commute_km', y='weekly_travel_distance_km', hue='ev_adoption_likelihood', size='annual_income', alpha=0.7)
plt.title(f'{plot_no}. Commute Distance, Weekly Travel and EV Adoption Relationship')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='current_vehicle_type', y='fuel_expense_per_month', estimator='mean', errorbar=None)
plt.title(f'{plot_no}. Average Monthly Fuel Expense by Current Vehicle Type')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='current_vehicle_type', y='vehicle_age_years')
plt.title(f'{plot_no}. Vehicle Age Distribution Across Vehicle Types')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.violinplot(data=df, x='ev_adoption_likelihood', y='nearest_charging_station_km', order=['Low', 'Medium', 'High'], inner='box')
plt.title(f'{plot_no}. Charging Station Proximity and EV Adoption Likelihood')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='home_charging_available', hue='ev_adoption_likelihood', hue_order=['Low', 'Medium', 'High'])
plt.xticks([0, 1], ['Not Available', 'Available'])
plt.title(f'{plot_no}. Impact of Home Charging Availability on EV Adoption')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='monthly_energy_consumption_kwh', y='monthly_charging_cost', hue='home_charging_available', alpha=0.7)
plt.title(f'{plot_no}. Energy Consumption Versus Monthly Charging Cost')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.regplot(data=df, x='electricity_cost_per_kwh', y='monthly_charging_cost', scatter_kws={'alpha': 0.5}, line_kws={'linewidth': 2})
plt.title(f'{plot_no}. Electricity Price Influence on Monthly Charging Cost')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='ev_adoption_likelihood', y='environmental_awareness_score', order=['Low', 'Medium', 'High'])
plt.title(f'{plot_no}. Environmental Awareness as a Driver of EV Adoption')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='ev_adoption_likelihood', y='technology_affinity_score', order=['Low', 'Medium', 'High'])
plt.title(f'{plot_no}. Technology Affinity Across EV Adoption Likelihood Levels')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='ev_adoption_likelihood', y='government_incentive_awareness', order=['Low', 'Medium', 'High'])
plt.title(f'{plot_no}. Government Incentive Awareness and EV Adoption Interest')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='range_anxiety_score', y='battery_replacement_concern', hue='ev_adoption_likelihood', alpha=0.7)
plt.title(f'{plot_no}. Range Anxiety and Battery Concern Among Potential EV Buyers')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='previous_ev_experience', y='range_anxiety_score')
plt.xticks([0, 1], ['No Previous Experience', 'Previous Experience'])
plt.title(f'{plot_no}. Previous EV Experience and Reduction in Range Anxiety')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='previous_ev_experience', hue='ev_adoption_likelihood', hue_order=['Low', 'Medium', 'High'])
plt.xticks([0, 1], ['No Previous Experience', 'Previous Experience'])
plt.title(f'{plot_no}. Previous EV Experience and Future Adoption Likelihood')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
adoption_profile = df.groupby('ev_adoption_likelihood')[['environmental_awareness_score', 'technology_affinity_score', 'range_anxiety_score', 'battery_replacement_concern']].mean().reindex(['Low', 'Medium', 'High'])
sns.heatmap(adoption_profile, annot=True, fmt='.2f', cmap='YlGnBu')
plt.title(f'{plot_no}. Average Consumer Attitude Profile by EV Adoption Likelihood')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(20, 12))
corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title(f'{plot_no}. Correlation Heatmap of Numerical EV Adoption Factors')
show_fig()
plot_no += 1

# %% [markdown]
# # Model Training

# %%
## Import libraries
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

## Separate features and target
X = df.drop(columns=['ev_adoption_likelihood'])
y = df['ev_adoption_likelihood']

## Select numerical and categorical columns
numerical_columns = X.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = X.select_dtypes(include=['object', 'category']).columns

## Prepare numerical features
numerical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

## Prepare categorical features
categorical_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

## Combine preprocessing steps
preprocessor = ColumnTransformer([
    ('numerical', numerical_pipeline, numerical_columns),
    ('categorical', categorical_pipeline, categorical_columns)
])

## Create SVM classification pipeline
model = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', SVC(kernel='rbf', C=10, gamma='scale', class_weight='balanced'))
])

## Split training and testing data
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

## Train the model
model.fit(X_train, y_train)

## Predict test data
y_pred = model.predict(X_test)

## Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

## Print model accuracy
print(f"Model Accuracy: {accuracy * 100:.2f}%")

## Print classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

## Create confusion matrix
labels = model.classes_
cm = confusion_matrix(y_test, y_pred, labels=labels)

## Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=labels,
    yticklabels=labels
)
plt.title('Actual vs Predicted EV Adoption Likelihood')
plt.xlabel('Predicted Class')
plt.ylabel('Actual Class')
plt.tight_layout()
plt.show()
# Out:
# Model Accuracy: 81.34%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         High       0.94      0.87      0.91      5934
#          Low       0.73      0.78      0.76      1650
#       Medium       0.60      0.69      0.64      2416
#
#     accuracy                           0.81     10000
#    macro avg       0.76      0.78      0.77     10000
# weighted avg       0.83      0.81      0.82     10000
