# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Import CSV and Convert to DataFrame

# %%
df = pd.read_csv('GTA Vice_City.csv')

# %% [markdown]
# # PreProcessing

# %% [markdown]
# ## Details of Dataset

# %% [markdown]
# ### Frist five row

# %%
df.head()
# Out:
#           id language                                             review  \
# 0  157337410  english  Games good, But Rockstar Your a BILLION DOLLAR...
# 1  157337371  english         modders make it better and free everything
# 2  157337210  english                                         great game
# 3  157336468  english                                               best
# 4  157335380  english                                                sed
#
#                created  voted_up  votes_up  comment_count  steam_purchase  \
# 0  2024-02-01 16:00:22      True         0              0            True
# 1  2024-02-01 15:59:57      True         0              0            True
# 2  2024-02-01 15:57:48      True         0              0           False
# 3  2024-02-01 15:47:51      True         0              0            True
# 4  2024-02-01 15:32:26      True         0              0            True
#
#    recieved_for_free  written_during_early_access  author_num_games_owned  \
# ...

# %% [markdown]
# ### last Five row

# %%
df.tail()
# Out:
#               id language                                             review  \
# 52094  140767442  english                                         great game
# 52095  140766922  english  This game destroys lives and breaks families. ...
# 52096  140766772  english  this is such a fun you need to try it out the ...
# 52097  140766435  english                                                 gg
# 52098  140766317  english  De los mejores juegos del mundo... Mas que nad...
#
#                    created  voted_up  votes_up  comment_count  steam_purchase  \
# 52094  2023-06-27 04:16:29      True         0              0            True
# 52095  2023-06-27 04:01:43     False         0              0            True
# 52096  2023-06-27 03:57:22      True         0              0            True
# 52097  2023-06-27 03:48:20      True         0              0            True
# 52098  2023-06-27 03:44:44      True         0              0            True
#
# ...

# %% [markdown]
# ### Shape of our dataset

# %%
df.shape
# Out:
# (52099, 16)

# %% [markdown]
# ### List out all columns

# %%
df.columns
# Out:
# Index(['id', 'language', 'review', 'created', 'voted_up', 'votes_up',
#        'comment_count', 'steam_purchase', 'recieved_for_free',
#        'written_during_early_access', 'author_num_games_owned',
#        'author_num_reviews', 'author_playtime_forever',
#        'author_playtime_last_two_weeks', 'author_playtime_at_review',
#        'author_last_played'],
#       dtype='object')

# %% [markdown]
# ### Datatype of each columns

# %%
df.dtypes
# Out:
# id                                 int64
# language                          object
# review                            object
# created                           object
# voted_up                            bool
# votes_up                           int64
# comment_count                      int64
# steam_purchase                      bool
# recieved_for_free                   bool
# written_during_early_access         bool
# author_num_games_owned             int64
# author_num_reviews                 int64
# author_playtime_forever            int64
# author_playtime_last_two_weeks     int64
# author_playtime_at_review          int64
# author_last_played                object
# dtype: object

# %% [markdown]
# ### Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52099 entries, 0 to 52098
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              52099 non-null  int64
#  1   language                        52099 non-null  object
#  2   review                          51801 non-null  object
#  3   created                         52099 non-null  object
#  4   voted_up                        52099 non-null  bool
#  5   votes_up                        52099 non-null  int64
#  6   comment_count                   52099 non-null  int64
#  7   steam_purchase                  52099 non-null  bool
#  8   recieved_for_free               52099 non-null  bool
#  9   written_during_early_access     52099 non-null  bool
#  10  author_num_games_owned          52099 non-null  int64
#  11  author_num_reviews              52099 non-null  int64
# ...

# %% [markdown]
# ### Check Null Value

# %%
df.isnull().sum()
# Out:
# id                                  0
# language                            0
# review                            298
# created                             0
# voted_up                            0
# votes_up                            0
# comment_count                       0
# steam_purchase                      0
# recieved_for_free                   0
# written_during_early_access         0
# author_num_games_owned              0
# author_num_reviews                  0
# author_playtime_forever             0
# author_playtime_last_two_weeks      0
# author_playtime_at_review           0
# author_last_played                  0
# dtype: int64

# %% [markdown]
# ### Check Duplicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### summary of the dataset

# %%
df.describe()
# Out:
#                  id      votes_up  comment_count  author_num_games_owned  \
# count  5.209900e+04  52099.000000   52099.000000            52099.000000
# mean   1.489459e+08      0.584387       0.018522               20.017467
# std    5.183634e+06     22.359856       0.352163              127.495124
# min    1.407663e+08      0.000000       0.000000                0.000000
# 25%    1.440101e+08      0.000000       0.000000                0.000000
# 50%    1.486648e+08      0.000000       0.000000                0.000000
# 75%    1.539681e+08      0.000000       0.000000                6.000000
# max    1.573374e+08   3942.000000      46.000000            18126.000000
#
#        author_num_reviews  author_playtime_forever  \
# count        52099.000000             5.209900e+04
# mean             5.844738             1.118878e+04
# std             12.600061             2.473005e+04
# min              1.000000             5.000000e+00
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ## Univariate

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
plt.figure(figsize=(8,4))
plt.hist(df['id'].dropna(), bins=20)
plt.title(f"{plot_no}. Distribution of ID")
show_fig()
plot_no += 1

# %%
df['created'] = pd.to_datetime(df['created'])

plt.figure(figsize=(12,4))
df['created'].dt.date.value_counts().sort_index().plot(kind='bar')
plt.title(f"{plot_no}. Review Count by Created Date")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
df['voted_up'].value_counts().plot(kind='bar')
plt.title(f"{plot_no}. Distribution of Voted Up")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
df['steam_purchase'].value_counts().plot(kind='bar')
plt.title(f"{plot_no}. Distribution of Steam Purchase")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
df['recieved_for_free'].value_counts().plot(kind='bar')
plt.title(f"{plot_no}. Distribution of Received for Free")
show_fig()
plot_no += 1

# %% [markdown]
# ## Bivariate

# %%
plt.figure(figsize=(8,4))
sns.countplot(x=df['steam_purchase'], hue=df['recieved_for_free'])
plt.title(f"{plot_no}. Steam Purchase vs Received for Free")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x=df['author_num_games_owned'], y=df['author_num_reviews'])
plt.title(f"{plot_no}. Games Owned vs Reviews Written")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x=df['author_playtime_forever'], y=df['author_playtime_at_review'])
plt.title(f"{plot_no}. Playtime Forever vs Playtime at Review")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
sns.countplot(x=df['language'], hue=df['voted_up'])
plt.title(f"{plot_no}. Language vs Voted Up")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
sns.countplot(x=df['voted_up'], hue=df['steam_purchase'])
plt.title(f"{plot_no}. Voted Up vs Steam Purchase")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
sns.countplot(x=df['recieved_for_free'], hue=df['voted_up'])
plt.title(f"{plot_no}. Received for Free vs Voted Up")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x=df['comment_count'], y=df['votes_up'])
plt.title(f"{plot_no}. Comment Count vs Votes Up")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x=df['author_num_reviews'], y=df['votes_up'])
plt.title(f"{plot_no}. Author Reviews vs Votes Up")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x=df['author_num_games_owned'], y=df['votes_up'])
plt.title(f"{plot_no}. Games Owned vs Votes Up")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
sns.countplot(x=df['written_during_early_access'], hue=df['voted_up'])
plt.title(f"{plot_no}. Written During Early Access vs Voted Up")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
sns.countplot(x=df['language'], hue=df['steam_purchase'])
plt.title(f"{plot_no}. Language vs Steam Purchase")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x=df['author_num_reviews'], y=df['author_playtime_forever'])
plt.title(f"{plot_no}. Author Reviews vs Playtime Forever")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')
plt.title(f"{plot_no}. Correlation Heatmap of Numeric Features")
show_fig()
plot_no += 1

# %% [markdown]
# ## Multivariate

# %%
plt.figure(figsize=(10,6))
sns.pairplot(df[['votes_up','comment_count','author_num_games_owned','author_num_reviews','author_playtime_forever','voted_up']], hue='voted_up')
plt.title(f"{plot_no}. Pairplot of Numeric Features Colored by Voted Up")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='language', hue='voted_up', data=df)
plt.title(f"{plot_no}. Language vs Voted Up vs Steam Purchase (Hue can be switched)")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df[df['voted_up']==True].select_dtypes(include='number').corr(), annot=True, cmap='YlGnBu')
plt.title(f"{plot_no}. Correlation Heatmap of Numeric Features (Voted Up = True)")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x=df['votes_up'], y=df['comment_count'], hue=df['voted_up'], palette='Set1')
plt.title(f"{plot_no}. Votes Up vs Comment Count Colored by Voted Up")
show_fig()
plot_no += 1

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x=df['author_playtime_forever'], y=df['author_num_reviews'],
                size=df['author_num_games_owned'], hue=df['voted_up'], palette='cool')
plt.title(f"{plot_no}. Playtime vs Reviews Sized by Games Owned & Colored by Voted Up")
show_fig()
plot_no += 1

# %%
g = sns.FacetGrid(df, col='language', hue='steam_purchase', height=4, aspect=1)
g.map(sns.scatterplot, 'votes_up', 'comment_count')
g.add_legend()
plt.subplots_adjust(top=0.8)
g.fig.suptitle(f"{plot_no}. Votes vs Comments by Steam Purchase Across Languages")
show_fig()
plot_no += 1

# %%
sns.pairplot(df[['votes_up','comment_count','author_num_reviews','author_playtime_forever','voted_up']],
             hue='voted_up', diag_kind='kde', palette='Set2')
plt.suptitle(f"{plot_no}. Pairplot of Numeric Features Colored by Voted Up", y=1.02)
show_fig()
plot_no += 1

# %% [markdown]
# # Prediction

# %% [markdown]
# ## Prepare Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# Select features and target
features = ['votes_up','comment_count','author_num_games_owned','author_num_reviews',
            'author_playtime_forever','author_playtime_last_two_weeks']
X = df[features]
y = df['voted_up'].astype(int)  # Convert boolean to 0/1

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Train Model

# %%
# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train Random Forest Classifier
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train_scaled, y_train)

# Predictions
y_pred = model.predict(X_test_scaled)

# Accuracy
acc = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {acc:.2f}")
# Out:
# Model Accuracy: 0.89

# %% [markdown]
# ## Plot Confusion Matrix

# %%
plt.figure(figsize=(6,4))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix for Voted Up Prediction")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ## Plot Feature Importance

# %%
plt.figure(figsize=(8,4))
importances = model.feature_importances_
sns.barplot(x=features, y=importances)
plt.title("Feature Importance for Voted Up Prediction")
plt.xticks(rotation=45)
plt.show()
