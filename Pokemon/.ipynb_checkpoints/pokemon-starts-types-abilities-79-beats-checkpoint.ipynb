# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download The PKMN DB Dataset](https://www.kaggle.com/datasets/malikajrjoyia/pokemon-statstypes-and-abilities-database)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
# Out:
# /kaggle/input/datasets/malikajrjoyia/pokemon-statstypes-and-abilities-database/PKMN_DB.csv
# /kaggle/input/datasets/malikajrjoyia/pokemon-statstypes-and-abilities-database/type_logos/type_logos/Flying.png
# /kaggle/input/datasets/malikajrjoyia/pokemon-statstypes-and-abilities-database/type_logos/type_logos/Steel.png
# /kaggle/input/datasets/malikajrjoyia/pokemon-statstypes-and-abilities-database/type_logos/type_logos/Grass.png
# /kaggle/input/datasets/malikajrjoyia/pokemon-statstypes-and-abilities-database/type_logos/type_logos/Poison.png
# /kaggle/input/datasets/malikajrjoyia/pokemon-statstypes-and-abilities-database/type_logos/type_logos/Fairy.png
# /kaggle/input/datasets/malikajrjoyia/pokemon-statstypes-and-abilities-database/type_logos/type_logos/Bug.png
# /kaggle/input/datasets/malikajrjoyia/pokemon-statstypes-and-abilities-database/type_logos/type_logos/Ghost.png
# /kaggle/input/datasets/malikajrjoyia/pokemon-statstypes-and-abilities-database/type_logos/type_logos/Dragon.png
# ...

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('PKMN_DB.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
df.head()
# Out:
#    Pokedex_Number   Pokemon_Name  Generation Type_1  Type_2  Ability_1  \
# 0               1      Bulbasaur           1  Grass  Poison   Overgrow
# 1               2        Ivysaur           1  Grass  Poison   Overgrow
# 2               3       Venusaur           1  Grass  Poison   Overgrow
# 3               4  Mega_Venusaur           6  Grass  Poison  Thick_Fat
# 4               5     Charmander           1   Fire     NaN      Blaze
#
#   Ability_2 Hidden_Ability  HP  Attack  Defense  Special_Attack  \
# 0       NaN    Chlorophyll  45      49       49              65
# 1       NaN    Chlorophyll  60      62       63              80
# 2       NaN    Chlorophyll  80      82       83             100
# 3       NaN            NaN  80     100      123             122
# 4       NaN    Solar_Power  39      52       43              60
#
#    Special_Defense  Speed  BST               Sub_Class  Stage
# 0               65     45  318                 Starter      1
# ...

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#       Pokedex_Number              Pokemon_Name  Generation  Type_1   Type_2  \
# 1256            1257                Iron_Crown           9   Steel  Psychic
# 1257            1258    Terapagos_Normal_Forme           9  Normal      NaN
# 1258            1259  Terapagos_Terastal_Forme           9  Normal      NaN
# 1259            1260   Terapagos_Stellar_Forme           9  Normal      NaN
# 1260            1261                 Pecharunt           9  Poison    Ghost
#
#              Ability_1 Ability_2 Hidden_Ability   HP  Attack  Defense  \
# 1256       Quark_Drive       NaN            NaN   90      72      100
# 1257        Tera_Shift       NaN            NaN   90      65       85
# 1258        Tera_Shell       NaN            NaN   95      95      110
# 1259     Teraform_Zero       NaN            NaN  160     105      110
# 1260  Poison_Puppeteer       NaN            NaN   88      88      160
#
#       Special_Attack  Special_Defense  Speed  BST            Sub_Class  Stage
# ...

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (1261, 17)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['Pokedex_Number', 'Pokemon_Name', 'Generation', 'Type_1', 'Type_2',
#        'Ability_1', 'Ability_2', 'Hidden_Ability', 'HP', 'Attack', 'Defense',
#        'Special_Attack', 'Special_Defense', 'Speed', 'BST', 'Sub_Class',
#        'Stage'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# Pokedex_Number      int64
# Pokemon_Name       object
# Generation          int64
# Type_1             object
# Type_2             object
# Ability_1          object
# Ability_2          object
# Hidden_Ability     object
# HP                  int64
# Attack              int64
# Defense             int64
# Special_Attack      int64
# Special_Defense     int64
# Speed               int64
# BST                 int64
# Sub_Class          object
# Stage               int64
# dtype: object

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1261 entries, 0 to 1260
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Pokedex_Number   1261 non-null   int64
#  1   Pokemon_Name     1261 non-null   object
#  2   Generation       1261 non-null   int64
#  3   Type_1           1261 non-null   object
#  4   Type_2           707 non-null    object
#  5   Ability_1        1246 non-null   object
#  6   Ability_2        587 non-null    object
#  7   Hidden_Ability   938 non-null    object
#  8   HP               1261 non-null   int64
#  9   Attack           1261 non-null   int64
#  10  Defense          1261 non-null   int64
#  11  Special_Attack   1261 non-null   int64
#  12  Special_Defense  1261 non-null   int64
#  13  Speed            1261 non-null   int64
#  14  BST              1261 non-null   int64
#  15  Sub_Class        1261 non-null   object
#  16  Stage            1261 non-null   int64
# ...

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# Pokedex_Number       0
# Pokemon_Name         0
# Generation           0
# Type_1               0
# Type_2             554
# Ability_1           15
# Ability_2          674
# Hidden_Ability     323
# HP                   0
# Attack               0
# Defense              0
# Special_Attack       0
# Special_Defense      0
# Speed                0
# BST                  0
# Sub_Class            0
# Stage                0
# dtype: int64

# %% [markdown]
# ## Drop Most Null Features

# %%
df.drop(columns=['Type_2', 'Ability_2', 'Hidden_Ability'], inplace=True)

# %% [markdown]
# ## Ability 1 fill with mode

# %%
df["Ability_1"] = df["Ability_1"].fillna(df["Ability_1"].mode()[0])

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#        Pokedex_Number   Generation           HP       Attack      Defense  \
# count     1261.000000  1261.000000  1261.000000  1261.000000  1261.000000
# mean       631.000000     5.179223    71.629659    82.426646    75.957970
# std        364.163654     2.656752    26.912735    32.749585    30.987872
# min          1.000000     1.000000     1.000000     5.000000     5.000000
# 25%        316.000000     3.000000    55.000000    60.000000    54.000000
# 50%        631.000000     5.000000    70.000000    80.000000    70.000000
# 75%        946.000000     8.000000    85.000000   102.000000    95.000000
# max       1261.000000     9.000000   255.000000   190.000000   250.000000
#
#        Special_Attack  Special_Defense        Speed          BST        Stage
# count     1261.000000      1261.000000  1261.000000  1261.000000  1261.000000
# mean        74.943695        73.580492    70.901665   449.440127     1.609040
# ...

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Generation', order=sorted(df['Generation'].unique()))
plt.title(f'{plot_no}. Distribution of Pokémon Across Generations')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Type_1', order=df['Type_1'].value_counts().index)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Primary Type Frequency Comparison')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['BST'], bins=30, kde=True)
plt.title(f'{plot_no}. Distribution of Base Stat Total (BST)')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Generation', y='BST')
plt.title(f'{plot_no}. Base Stat Total Variation Across Generations')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Attack', y='Defense', hue='Type_1')
plt.title(f'{plot_no}. Attack vs Defense by Primary Type')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Special_Attack', y='Special_Defense', hue='Generation')
plt.title(f'{plot_no}. Special Attack vs Special Defense by Generation')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Speed', y='BST', hue='Stage')
plt.title(f'{plot_no}. Speed Influence on Overall Base Stat Total')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Stage', y='BST')
plt.title(f'{plot_no}. Evolution Stage vs Base Stat Total')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
top_abilities = df['Ability_1'].value_counts().head(10).index
sns.countplot(data=df[df['Ability_1'].isin(top_abilities)], x='Ability_1', order=top_abilities)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Top 10 Most Common Primary Abilities')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Generation', y='BST', estimator='mean')
plt.title(f'{plot_no}. Average Base Stat Total by Generation')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Stage', y='Attack', estimator='mean')
plt.title(f'{plot_no}. Average Attack Across Evolution Stages')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Stage', y='Speed', estimator='mean')
plt.title(f'{plot_no}. Average Speed Across Evolution Stages')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='HP', y='Defense', size='BST', hue='Generation')
plt.title(f'{plot_no}. HP vs Defense with Overall Strength Indication')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.regplot(data=df, x='Attack', y='BST', scatter_kws={'alpha':0.6})
plt.title(f'{plot_no}. Relationship Between Attack and Base Stat Total')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.regplot(data=df, x='Speed', y='BST', scatter_kws={'alpha':0.6})
plt.title(f'{plot_no}. Relationship Between Speed and Base Stat Total')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Type_1', y='Attack', order=df.groupby('Type_1')['Attack'].mean().sort_values(ascending=False).index)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Attack Strength Distribution by Primary Type')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Type_1', y='Speed', order=df.groupby('Type_1')['Speed'].mean().sort_values(ascending=False).index)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Speed Distribution Across Primary Pokémon Types')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.pairplot(df[['HP','Attack','Defense','Special_Attack','Special_Defense','Speed']])
plt.suptitle(f'{plot_no}. Pairwise Relationships Among Core Battle Statistics', y=1.02)
plt.show()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title(f'{plot_no}. Correlation Heatmap of Numerical Pokémon Attributes')
show_fig()
plot_no += 1

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Create copy of dataset

# %%
data = df.copy()

# %% [markdown]
# ## Remove missing values

# %%
data = data.dropna()

# %% [markdown]
# ## Define target column

# %%
target = "Stage"

# %% [markdown]
# ## Create feature and target datasets

# %%
X = data.drop(columns=[target, "Pokemon_Name"], errors="ignore")
y = data[target]

# %% [markdown]
# ## Find numeric and categorical columns

# %%
numeric_features = X.select_dtypes(include=["int64", "float64"]).columns
categorical_features = X.select_dtypes(include=["object", "category"]).columns

# %% [markdown]
# ## Create preprocessing pipeline

# %%
numeric_transformer = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

categorical_transformer = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

preprocessor = ColumnTransformer([
    ("num", numeric_transformer, numeric_features),
    ("cat", categorical_transformer, categorical_features)
])

# %% [markdown]
# ## Split the dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %% [markdown]
# ## Build upgraded Gradient Boosting model

# %%
model = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", GradientBoostingClassifier(
        n_estimators=300,
        learning_rate=0.05,
        max_depth=4,
        random_state=42
    ))
])

# %% [markdown]
# ## Train the model

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['Pokedex_Number', 'Generation', 'HP', 'Attack', 'Defense',
#        'Special_Attack', 'Special_Defense', 'Speed', 'BST'],
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
# ...

# %% [markdown]
# ## Predict on test data

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Print model accuracy

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy Score : {accuracy*100:.2f}%")
# Out:
# Accuracy Score : 79.05%

# %% [markdown]
# ## Print classification report

# %%
print("\nClassification Report\n")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report
#
#               precision    recall  f1-score   support
#
#            1       0.88      0.86      0.87       132
#            2       0.67      0.80      0.73        88
#            3       0.84      0.48      0.62        33
#
#     accuracy                           0.79       253
#    macro avg       0.80      0.71      0.74       253
# weighted avg       0.80      0.79      0.79       253

# %% [markdown]
# ## Plot confusion matrix

# %%
fig = plt.figure(figsize=(8,6))
ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred,
    cmap="Blues"
)
plt.title("Actual vs Predicted (Confusion Matrix)")
plt.tight_layout()
plt.show()
