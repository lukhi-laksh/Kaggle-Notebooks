# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download The Climate Trend Dataset](https://www.kaggle.com/datasets/mirzayasirabdullah07/climate-trend-dataset-5000-rows)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# /kaggle/input/datasets/mirzayasirabdullah07/climate-trend-dataset-5000-rows/climate_trend_dataset_5000_rows.csv

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('climate_trend_dataset_5000_rows.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
df.head()
# Out:
#          date   region  avg_temperature_c  precipitation_mm  co2_ppm  \
# 0  2010-01-01     West               3.37             47.39   388.64
# 1  2010-01-02  Central              13.50             22.00   391.97
# 2  2010-01-03     East              10.85             83.16   387.47
# 3  2010-01-04  Central               8.48             50.35   391.20
# 4  2010-01-05  Central              10.05             64.55   388.14
#
#    temperature_anomaly_c  humidity_percent
# 0                  -0.24             53.69
# 1                   0.05             81.52
# 2                  -0.33             59.11
# 3                  -0.53             51.05
# 4                   0.02             70.34

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#             date   region  avg_temperature_c  precipitation_mm  co2_ppm  \
# 4995  2023-09-05     West              24.16             82.52   437.06
# 4996  2023-09-06     West              18.55             45.52   436.89
# 4997  2023-09-07  Central              15.26             48.55   435.75
# 4998  2023-09-08     West              19.37             79.80   434.78
# 4999  2023-09-09  Central              15.32             66.31   435.77
#
#       temperature_anomaly_c  humidity_percent
# 4995                   2.81             70.32
# 4996                   2.13             46.14
# 4997                   2.91             63.42
# 4998                   2.05             46.93
# 4999                   2.26             72.63

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (5000, 7)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['date', 'region', 'avg_temperature_c', 'precipitation_mm', 'co2_ppm',
#        'temperature_anomaly_c', 'humidity_percent'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# date                      object
# region                    object
# avg_temperature_c        float64
# precipitation_mm         float64
# co2_ppm                  float64
# temperature_anomaly_c    float64
# humidity_percent         float64
# dtype: object

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   5000 non-null   object
#  1   region                 5000 non-null   object
#  2   avg_temperature_c      5000 non-null   float64
#  3   precipitation_mm       5000 non-null   float64
#  4   co2_ppm                5000 non-null   float64
#  5   temperature_anomaly_c  5000 non-null   float64
#  6   humidity_percent       5000 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 273.6+ KB

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# date                     0
# region                   0
# avg_temperature_c        0
# precipitation_mm         0
# co2_ppm                  0
# temperature_anomaly_c    0
# humidity_percent         0
# dtype: int64

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#        avg_temperature_c  precipitation_mm      co2_ppm  \
# count        5000.000000        5000.00000  5000.000000
# mean           16.149176          60.17607   412.541154
# std             4.147459          24.25512    13.081580
# min             2.480000           0.22000   387.470000
# 25%            13.387500          43.66750   401.270000
# 50%            16.140000          59.98500   412.500000
# 75%            18.910000          76.34250   423.852500
# max            30.990000         144.44000   439.060000
#
#        temperature_anomaly_c  humidity_percent
# count            5000.000000       5000.000000
# mean                1.246596         65.035242
# std                 0.777739         11.741166
# min                -0.970000         23.060000
# 25%                 0.620000         56.827500
# 50%                 1.250000         65.120000
# 75%                 1.870000         72.920000
# max                 3.150000        100.000000

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['avg_temperature_c'], bins=30, kde=True)
plt.title(f'{plot_no}. Distribution of Average Temperature')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['precipitation_mm'], bins=30, kde=True)
plt.title(f'{plot_no}. Distribution of Daily Precipitation')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['co2_ppm'], bins=30, kde=True)
plt.title(f'{plot_no}. Distribution of Atmospheric CO₂ Levels')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['humidity_percent'], bins=30, kde=True)
plt.title(f'{plot_no}. Distribution of Humidity Percentage')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='region', y='avg_temperature_c', data=df)
plt.title(f'{plot_no}. Regional Comparison of Average Temperature')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='region', y='precipitation_mm', data=df)
plt.title(f'{plot_no}. Regional Variation in Daily Precipitation')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='region', y='humidity_percent', data=df)
plt.title(f'{plot_no}. Regional Distribution of Humidity Levels')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='region', y='co2_ppm', data=df)
plt.title(f'{plot_no}. Regional Comparison of Atmospheric CO₂ Concentration')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='co2_ppm', y='avg_temperature_c', hue='region')
plt.title(f'{plot_no}. CO₂ Concentration vs Average Temperature by Region')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='humidity_percent', y='avg_temperature_c', hue='region')
plt.title(f'{plot_no}. Humidity Influence on Average Temperature')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='precipitation_mm', y='humidity_percent', hue='region')
plt.title(f'{plot_no}. Relationship Between Precipitation and Humidity')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='temperature_anomaly_c', y='avg_temperature_c', hue='region')
plt.title(f'{plot_no}. Temperature Anomaly Compared with Average Temperature')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='co2_ppm', y='temperature_anomaly_c', hue='region')
plt.title(f'{plot_no}. CO₂ Levels and Temperature Anomalies')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.violinplot(x='region', y='temperature_anomaly_c', data=df)
plt.title(f'{plot_no}. Distribution of Temperature Anomalies Across Regions')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.violinplot(x='region', y='co2_ppm', data=df)
plt.title(f'{plot_no}. Atmospheric CO₂ Distribution by Region')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(x='region', data=df)
plt.title(f'{plot_no}. Number of Records Available by Region')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.regplot(data=df, x='co2_ppm', y='avg_temperature_c', scatter_kws={'alpha':0.5})
plt.title(f'{plot_no}. Regression Trend Between CO₂ Levels and Temperature')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.regplot(data=df, x='precipitation_mm', y='humidity_percent', scatter_kws={'alpha':0.5})
plt.title(f'{plot_no}. Regression Analysis of Precipitation and Humidity')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.pairplot(df[['avg_temperature_c','precipitation_mm','co2_ppm','temperature_anomaly_c','humidity_percent']])
plt.suptitle(f'{plot_no}. Pairwise Relationships Among Climate Variables', y=1.02)
plt.show()
plot_no += 1

# %%
corr = df[['avg_temperature_c','precipitation_mm','co2_ppm','temperature_anomaly_c','humidity_percent']].corr()

fig = plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title(f'{plot_no}. Correlation Heatmap of Climate Variables')
show_fig()
plot_no += 1
