# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download The Indian Road Accident Dataset](https://www.kaggle.com/datasets/sehaj1104/indian-road-accident-dataset-20222025/data)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('indian_roads_dataset.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
df.head()
# Out:
#    accident_id        city        state   latitude  longitude        date  \
# 0            0        Pune  Maharashtra  18.680827  73.930388  2023-10-22
# 1            1      Mumbai  Maharashtra  18.817732  72.790846  2023-05-21
# 2            2      Mumbai  Maharashtra  19.096889  72.819424  2024-07-10
# 3            3  Chandigarh       Punjab  30.787805  76.847507  2025-03-30
# 4            4     Chennai   Tamil Nadu  12.965155  80.283313  2024-01-25
#
#     time  hour day_of_week  is_weekend  ... visibility  temperature  \
# 0   5:00     5      Sunday           1  ...        low           32
# 1   4:00     4      Sunday           1  ...       high           34
# 2  13:00    13   Wednesday           0  ...        low           21
# 3  11:00    11      Sunday           1  ...        low           30
# 4  16:00    16    Thursday           0  ...       high           24
#
#    traffic_density        cause accident_severity  vehicles_involved  \
# ...

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#        accident_id       city        state   latitude  longitude        date  \
# 19995        19995  Bangalore    Karnataka  13.092276  77.599571  2022-09-29
# 19996        19996    Chennai   Tamil Nadu  13.172928  80.157062  2023-11-25
# 19997        19997    Chennai   Tamil Nadu  12.997170  80.150724  2022-06-18
# 19998        19998    Kolkata  West Bengal  22.454882  88.322213  2023-03-12
# 19999        19999      Delhi        Delhi  28.510266  77.065301  2024-07-05
#
#         time  hour day_of_week  is_weekend  ... visibility  temperature  \
# 19995   3:00     3    Thursday           0  ...       high           31
# 19996   1:00     1    Saturday           1  ...       high           20
# 19997  15:00    15    Saturday           1  ...       high           22
# 19998   4:00     4      Sunday           1  ...       high           33
# 19999  23:00    23      Friday           0  ...        low           39
#
# ...

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (20000, 24)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['accident_id', 'city', 'state', 'latitude', 'longitude', 'date', 'time',
#        'hour', 'day_of_week', 'is_weekend', 'road_type', 'lanes',
#        'traffic_signal', 'weather', 'visibility', 'temperature',
#        'traffic_density', 'cause', 'accident_severity', 'vehicles_involved',
#        'casualties', 'is_peak_hour', 'festival', 'risk_score'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# accident_id            int64
# city                  object
# state                 object
# latitude             float64
# longitude            float64
# date                  object
# time                  object
# hour                   int64
# day_of_week           object
# is_weekend             int64
# road_type             object
# lanes                  int64
# traffic_signal         int64
# weather               object
# visibility            object
# temperature            int64
# traffic_density       object
# cause                 object
# accident_severity     object
# vehicles_involved      int64
# casualties             int64
# is_peak_hour           int64
# festival              object
# risk_score           float64
# dtype: object

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   accident_id        20000 non-null  int64
#  1   city               20000 non-null  object
#  2   state              20000 non-null  object
#  3   latitude           20000 non-null  float64
#  4   longitude          20000 non-null  float64
#  5   date               20000 non-null  object
#  6   time               20000 non-null  object
#  7   hour               20000 non-null  int64
#  8   day_of_week        20000 non-null  object
#  9   is_weekend         20000 non-null  int64
#  10  road_type          20000 non-null  object
#  11  lanes              20000 non-null  int64
#  12  traffic_signal     20000 non-null  int64
#  13  weather            20000 non-null  object
#  14  visibility         20000 non-null  object
#  15  temperature        20000 non-null  int64
# ...

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# accident_id              0
# city                     0
# state                    0
# latitude                 0
# longitude                0
# date                     0
# time                     0
# hour                     0
# day_of_week              0
# is_weekend               0
# road_type                0
# lanes                    0
# traffic_signal           0
# weather                  0
# visibility               0
# temperature              0
# traffic_density          0
# cause                    0
# accident_severity        0
# vehicles_involved        0
# casualties               0
# is_peak_hour             0
# festival             19885
# risk_score               0
# dtype: int64

# %% [markdown]
# ## Drop Festival Column

# %%
df.drop(columns=['festival'], inplace=True)

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#         accident_id      latitude     longitude          hour    is_weekend  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean    9999.500000     20.389207     78.173330     11.487200      0.286150
# std     5773.647028      6.165791      4.485967      6.945563      0.451972
# min        0.000000     12.800172     72.700017      0.000000      0.000000
# 25%     4999.750000     13.198653     73.997979      5.000000      0.000000
# 50%     9999.500000     18.812008     77.297000     12.000000      0.000000
# 75%    14999.250000     28.402467     80.111089     18.000000      1.000000
# max    19999.000000     30.799960     88.499861     23.000000      1.000000
#
#               lanes  traffic_signal   temperature  vehicles_involved  \
# count  20000.000000    20000.000000  20000.000000       20000.000000
# mean       3.493950        0.499850     27.579600           2.992000
# std        1.705406        0.500012      7.454746           1.415534
# ...

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(x='accident_severity', data=df)
plt.title(f'{plot_no}. Distribution of Accident Severity Levels')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(x='city', data=df, order=df['city'].value_counts().index)
plt.xticks(rotation=90)
plt.title(f'{plot_no}. Accident Frequency Across Cities')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(x='day_of_week', data=df, order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
plt.title(f'{plot_no}. Accidents by Day of Week Pattern')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(x='hour', data=df)
plt.title(f'{plot_no}. Hourly Distribution of Accidents')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='accident_severity', y='risk_score', data=df)
plt.title(f'{plot_no}. Risk Score Variation by Accident Severity')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['risk_score'], bins=30, kde=True)
plt.title(f'{plot_no}. Distribution of Risk Scores')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(x='traffic_density', hue='accident_severity', data=df)
plt.title(f'{plot_no}. Impact of Traffic Density on Accident Severity')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(x='visibility', hue='accident_severity', data=df)
plt.title(f'{plot_no}. Visibility Conditions vs Accident Severity')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='temperature', y='risk_score', hue='accident_severity', data=df)
plt.title(f'{plot_no}. Temperature Influence on Risk Score and Severity')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='is_weekend', y='risk_score', data=df)
plt.title(f'{plot_no}. Weekend vs Weekday Risk Score Comparison')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(x='cause', data=df, order=df['cause'].value_counts().index)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Major Causes of Accidents')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(x='cause', hue='accident_severity', data=df)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Accident Causes by Severity Level')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='accident_severity', y='vehicles_involved', data=df)
plt.title(f'{plot_no}. Vehicles Involved Across Severity Levels')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='accident_severity', y='casualties', data=df)
plt.title(f'{plot_no}. Casualties Distribution by Severity Level')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(x='is_peak_hour', hue='accident_severity', data=df)
plt.title(f'{plot_no}. Peak Hour Influence on Accident Severity')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title(f'{plot_no}. Correlation Heatmap of Numerical Features')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.violinplot(x='traffic_density', y='risk_score', data=df)
plt.title(f'{plot_no}. Risk Score Distribution Across Traffic Density Levels')
show_fig()
plot_no += 1
