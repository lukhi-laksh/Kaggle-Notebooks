# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download The Amazon Dataset](https://www.kaggle.com/datasets/prabhanshukamal2121/e-commerce-recommendation?select=amazon_synthetic_data_abandonment_propensity_32_features.csv)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay
# Out:
# /kaggle/input/datasets/prabhanshukamal2121/e-commerce-recommendation/amazon_synthetic_data_model_3_sessions.csv
# /kaggle/input/datasets/prabhanshukamal2121/e-commerce-recommendation/amazon_synthetic_data_catalog.csv
# /kaggle/input/datasets/prabhanshukamal2121/e-commerce-recommendation/amazon_synthetic_data_model_1_interactions.csv
# /kaggle/input/datasets/prabhanshukamal2121/e-commerce-recommendation/amazon_synthetic_data_abandonment_propensity_32_features.csv
# /kaggle/input/datasets/prabhanshukamal2121/e-commerce-recommendation/amazon_synthetic_data_model_2_baskets (1).csv

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('amazon_synthetic_data_abandonment_propensity_32_features.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#       user_id   session_id  customer_tier  account_age_days  \
# 0  CUST_00001  SESS_000001       Standard               853
# 1  CUST_00002  SESS_000002  Prime Student               257
# 2  CUST_00003  SESS_000003          Prime              1411
# 3  CUST_00004  SESS_000004       Standard                44
# 4  CUST_00005  SESS_000005          Guest               268
#
#    past_purchases_count  total_lifetime_value  average_order_value  \
# 0                     1                 45.98                45.98
# 1                    10               1416.37               141.64
# 2                     3                448.10               149.37
# 3                     8                714.27                89.28
# 4                    17               2344.24               137.90
#
#    days_since_last_purchase  days_since_last_discount device_type browser  \
# 0                        12                        25      Mobile  Chrome
# ...

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#           user_id   session_id customer_tier  account_age_days  \
# 19995  CUST_19996  SESS_019996         Prime                69
# 19996  CUST_19997  SESS_019997         Guest               184
# 19997  CUST_19998  SESS_019998      Standard              1461
# 19998  CUST_19999  SESS_019999      Standard               571
# 19999  CUST_20000  SESS_020000         Guest              1497
#
#        past_purchases_count  total_lifetime_value  average_order_value  \
# 19995                     2                211.56               105.78
# 19996                     0                  0.00                 0.00
# 19997                     6                142.03                23.67
# 19998                    34               3592.68               105.67
# 19999                     4                306.61                76.65
#
#        days_since_last_purchase  days_since_last_discount device_type browser  \
# ...

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (20000, 32)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['user_id', 'session_id', 'customer_tier', 'account_age_days',
#        'past_purchases_count', 'total_lifetime_value', 'average_order_value',
#        'days_since_last_purchase', 'days_since_last_discount', 'device_type',
#        'browser', 'traffic_source', 'user_location_region', 'day_of_week',
#        'hour_of_day', 'is_weekend', 'is_holiday', 'session_duration_seconds',
#        'pages_viewed', 'distinct_categories_viewed', 'pdp_views_count',
#        'images_viewed_count', 'reviews_read_count', 'scroll_depth_average_pct',
#        'add_to_cart_count', 'remove_from_cart_count', 'wishlist_add_count',
#        'cart_value_abandoned', 'shipping_cost_displayed',
#        'exit_intent_triggered', 'did_convert_organically',
#        'should_receive_discount'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# user_id                        object
# session_id                     object
# customer_tier                  object
# account_age_days                int64
# past_purchases_count            int64
# total_lifetime_value          float64
# average_order_value           float64
# days_since_last_purchase        int64
# days_since_last_discount        int64
# device_type                    object
# browser                        object
# traffic_source                 object
# user_location_region           object
# day_of_week                     int64
# hour_of_day                     int64
# is_weekend                      int64
# is_holiday                      int64
# session_duration_seconds        int64
# pages_viewed                    int64
# distinct_categories_viewed      int64
# pdp_views_count                 int64
# images_viewed_count             int64
# reviews_read_count              int64
# scroll_depth_average_pct      float64
# add_to_cart_count               int64
# ...

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   user_id                     20000 non-null  object
#  1   session_id                  20000 non-null  object
#  2   customer_tier               20000 non-null  object
#  3   account_age_days            20000 non-null  int64
#  4   past_purchases_count        20000 non-null  int64
#  5   total_lifetime_value        20000 non-null  float64
#  6   average_order_value         20000 non-null  float64
#  7   days_since_last_purchase    20000 non-null  int64
#  8   days_since_last_discount    20000 non-null  int64
#  9   device_type                 20000 non-null  object
#  10  browser                     20000 non-null  object
#  11  traffic_source              20000 non-null  object
#  12  user_location_region        20000 non-null  object
# ...

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# user_id                       0
# session_id                    0
# customer_tier                 0
# account_age_days              0
# past_purchases_count          0
# total_lifetime_value          0
# average_order_value           0
# days_since_last_purchase      0
# days_since_last_discount      0
# device_type                   0
# browser                       0
# traffic_source                0
# user_location_region          0
# day_of_week                   0
# hour_of_day                   0
# is_weekend                    0
# is_holiday                    0
# session_duration_seconds      0
# pages_viewed                  0
# distinct_categories_viewed    0
# pdp_views_count               0
# images_viewed_count           0
# reviews_read_count            0
# scroll_depth_average_pct      0
# add_to_cart_count             0
# remove_from_cart_count        0
# wishlist_add_count            0
# cart_value_abandoned          0
# shipping_cost_displayed       0
# ...

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#        account_age_days  past_purchases_count  total_lifetime_value  \
# count      20000.000000          20000.000000          20000.000000
# mean         897.706700              9.029350            766.115538
# std          518.626125              9.517968            940.249991
# min            0.000000              0.000000              0.000000
# 25%          447.000000              2.000000            147.392500
# 50%          900.000000              6.000000            440.400000
# 75%         1347.000000             13.000000           1018.680000
# max         1799.000000             99.000000           9025.620000
#
#        average_order_value  days_since_last_purchase  \
# count         20000.000000              20000.000000
# mean             76.333816                165.001950
# std              43.771779                114.176062
# min               0.000000                 -1.000000
# 25%              41.507500                 61.000000
# ...

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['total_lifetime_value'], kde=True)
plt.title(f'{plot_no}. Distribution of Total Lifetime Customer Value')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['session_duration_seconds'], kde=True)
plt.title(f'{plot_no}. Distribution of Customer Session Duration')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='customer_tier', y='total_lifetime_value')
plt.title(f'{plot_no}. Lifetime Customer Value Across Customer Tiers')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='customer_tier', y='average_order_value', estimator='mean')
plt.title(f'{plot_no}. Average Order Value Across Customer Tiers')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(14,10))
corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title(f'{plot_no}. Correlation Heatmap of Customer, Session and Conversion Metrics')
show_fig()
plot_no += 1

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Select target and remove identifiers

# %%
X = df.drop(columns=['did_convert_organically', 'user_id', 'session_id'])
y = df['did_convert_organically']

# %% [markdown]
# ## Remove highly redundant features

# %%
X = X.drop(columns=[
    'pdp_views_count',
    'images_viewed_count',
    'reviews_read_count',
    'is_weekend'
], errors='ignore')

# %% [markdown]
# ## Identify feature types

# %%
numeric_features = X.select_dtypes(include=np.number).columns
categorical_features = X.select_dtypes(exclude=np.number).columns

# %% [markdown]
# ## Build preprocessing pipeline

# %%
preprocessor = ColumnTransformer([
    ('num', Pipeline([
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ]), numeric_features),
    ('cat', Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('encoder', OneHotEncoder(handle_unknown='ignore'))
    ]), categorical_features)
])

# %% [markdown]
# ## Split data with stratification

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.30,
    random_state=42,
    stratify=y
)

# %% [markdown]
# ## Train strongly regularized logistic regression

# %%
model = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(
        C=0.03,
        penalty='l2',
        solver='liblinear',
        max_iter=1000,
        random_state=42
    ))
])

# %% [markdown]
# ## Train the model

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['account_age_days', 'past_purchases_count', 'total_lifetime_value',
#        'average_order_value', 'days_since_last_purchase',
#        'days_since_last_discount', 'day_of_week', 'hour_of_day', 'is_holiday'...
#        'exit_intent_triggered', 'should_receive_discount'],
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
# ...

# %% [markdown]
# ## Generate predictions

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %% [markdown]
# ## Calculate accuracy

# %%
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# %% [markdown]
# ## Print model performance

# %%
print(f"Training Accuracy: {train_accuracy:.2%}")
print(f"Testing Accuracy: {test_accuracy:.2%}")
print(f"Overfitting Gap: {(train_accuracy - test_accuracy):.2%}")
# Out:
# Training Accuracy: 84.59%
# Testing Accuracy: 84.37%
# Overfitting Gap: 0.23%

# %% [markdown]
# ## Plot confusion matrix

# %%
fig = plt.figure(figsize=(8,6))
ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_test_pred,
    cmap='Blues',
    values_format='d'
)
plt.title('Confusion Matrix - Regularized Logistic Regression')
plt.tight_layout()
plt.show()
