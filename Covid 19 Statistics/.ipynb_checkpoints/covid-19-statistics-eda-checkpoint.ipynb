# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download The Covid 19 Statistics EDA Dataset](https://www.kaggle.com/datasets/harshadapatil31/covid-19-statistics)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# /kaggle/input/datasets/harshadapatil31/covid-19-statistics/COVID19_Statistics_200_Rows-1.csv

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('COVID19_Statistics_200_Rows-1.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
df.head()
# Out:
#    Record_ID        Date Country       State  Confirmed  Recovered  Deaths  \
# 0          1  2021-01-02     USA  California       4107       3518      70
# 1          2  2021-01-03  Brazil   Sao Paulo     112163     102717    2474
# 2          3  2021-01-04   Japan       Tokyo     220599     191161    5182
# 3          4  2021-01-05      UK     England     445177     347729    8113
# 4          5  2021-01-06      UK     England     241776     192943    3413
#
#    Active  Tests_Conducted  Vaccination_Rate_%
# 0     519            10528                  99
# 1    6972           438420                  59
# 2   24256           469235                  35
# 3   89335           452508                  73
# 4   45420           312154                  70

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#      Record_ID        Date Country        State  Confirmed  Recovered  Deaths  \
# 195        196  2021-07-16   Japan        Tokyo     115516      90567    1413
# 196        197  2021-07-17  Brazil    Sao Paulo     294730     227226    1002
# 197        198  2021-07-18   Japan        Tokyo      53510      44179      58
# 198        199  2021-07-19     USA   California     157701     123045    4597
# 199        200  2021-07-20   India  Maharashtra     141681     123688     805
#
#      Active  Tests_Conducted  Vaccination_Rate_%
# 195   23536           118084                  23
# 196   66502          1186057                  76
# 197    9273            76248                  47
# 198   30059           468950                  71
# 199   17188           539202                  25

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (200, 10)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['Record_ID', 'Date', 'Country', 'State', 'Confirmed', 'Recovered',
#        'Deaths', 'Active', 'Tests_Conducted', 'Vaccination_Rate_%'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# Record_ID              int64
# Date                  object
# Country               object
# State                 object
# Confirmed              int64
# Recovered              int64
# Deaths                 int64
# Active                 int64
# Tests_Conducted        int64
# Vaccination_Rate_%     int64
# dtype: object

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Record_ID           200 non-null    int64
#  1   Date                200 non-null    object
#  2   Country             200 non-null    object
#  3   State               200 non-null    object
#  4   Confirmed           200 non-null    int64
#  5   Recovered           200 non-null    int64
#  6   Deaths              200 non-null    int64
#  7   Active              200 non-null    int64
#  8   Tests_Conducted     200 non-null    int64
#  9   Vaccination_Rate_%  200 non-null    int64
# dtypes: int64(7), object(3)
# memory usage: 15.8+ KB

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# Record_ID             0
# Date                  0
# Country               0
# State                 0
# Confirmed             0
# Recovered             0
# Deaths                0
# Active                0
# Tests_Conducted       0
# Vaccination_Rate_%    0
# dtype: int64

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#         Record_ID      Confirmed      Recovered        Deaths         Active  \
# count  200.000000     200.000000     200.000000    200.000000     200.000000
# mean   100.500000  246900.925000  210518.205000   3766.560000   32852.280000
# std     57.879185  144278.001022  126369.024284   3187.914286   31283.667031
# min      1.000000    1124.000000     847.000000     13.000000       0.000000
# 25%     50.750000  114969.750000   98422.750000   1058.000000    8433.250000
# 50%    100.500000  246254.000000  213177.500000   3100.000000   23296.000000
# 75%    150.250000  374580.750000  312515.500000   5897.500000   47646.000000
# max    200.000000  486407.000000  486353.000000  13969.000000  134405.000000
#
#        Tests_Conducted  Vaccination_Rate_%
# count     2.000000e+02           200.00000
# mean      7.315664e+05            57.95500
# std       5.357430e+05            25.93988
# min       5.440000e+03            10.00000
# 25%       3.123678e+05            37.00000
# ...

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['Confirmed'], bins=30, kde=True)
plt.title(f'{plot_no}. Distribution of Confirmed COVID-19 Cases')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['Recovered'], bins=30, kde=True, color='green')
plt.title(f'{plot_no}. Distribution of Recovered Cases')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['Deaths'], bins=30, kde=True, color='red')
plt.title(f'{plot_no}. Distribution of COVID-19 Deaths')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Confirmed', y='Recovered', alpha=0.7)
plt.title(f'{plot_no}. Relationship Between Confirmed and Recovered Cases')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Confirmed', y='Deaths', alpha=0.7, color='red')
plt.title(f'{plot_no}. Impact of Confirmed Cases on Death Count')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Tests_Conducted', y='Confirmed', alpha=0.7)
plt.title(f'{plot_no}. Testing Volume vs Confirmed Cases')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Vaccination_Rate_%', y='Confirmed', alpha=0.7)
plt.title(f'{plot_no}. Vaccination Rate vs Confirmed Cases')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Vaccination_Rate_%', y='Deaths', alpha=0.7, color='purple')
plt.title(f'{plot_no}. Vaccination Rate vs Death Count')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Vaccination_Rate_%', y='Recovered', alpha=0.7, color='green')
plt.title(f'{plot_no}. Vaccination Rate vs Recovery Count')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Country', y='Confirmed')
plt.xticks(rotation=90)
plt.title(f'{plot_no}. Country-wise Distribution of Confirmed Cases')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Country', y='Deaths')
plt.xticks(rotation=90)
plt.title(f'{plot_no}. Country-wise Distribution of Deaths')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Country', y='Vaccination_Rate_%')
plt.xticks(rotation=90)
plt.title(f'{plot_no}. Country-wise Vaccination Rate Distribution')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
country_confirmed = df.groupby('Country')['Confirmed'].mean().sort_values(ascending=False)
sns.barplot(x=country_confirmed.index, y=country_confirmed.values)
plt.xticks(rotation=90)
plt.title(f'{plot_no}. Average Confirmed Cases by Country')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
country_deaths = df.groupby('Country')['Deaths'].mean().sort_values(ascending=False)
sns.barplot(x=country_deaths.index, y=country_deaths.values)
plt.xticks(rotation=90)
plt.title(f'{plot_no}. Average Death Count by Country')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
country_vacc = df.groupby('Country')['Vaccination_Rate_%'].mean().sort_values(ascending=False)
sns.barplot(x=country_vacc.index, y=country_vacc.values)
plt.xticks(rotation=90)
plt.title(f'{plot_no}. Average Vaccination Rate by Country')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
daily_confirmed = df.groupby('Date')['Confirmed'].sum()
plt.plot(daily_confirmed.index, daily_confirmed.values, marker='o')
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Daily Trend of Confirmed Cases')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
daily_deaths = df.groupby('Date')['Deaths'].sum()
plt.plot(daily_deaths.index, daily_deaths.values, marker='o', color='red')
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Daily Trend of COVID-19 Deaths')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
daily_vacc = df.groupby('Date')['Vaccination_Rate_%'].mean()
plt.plot(daily_vacc.index, daily_vacc.values, marker='o', color='green')
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Daily Average Vaccination Rate')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.pairplot(df[['Confirmed','Recovered','Deaths','Active','Tests_Conducted','Vaccination_Rate_%']])
plt.suptitle(f'{plot_no}. Pairwise Relationships Among Key COVID-19 Metrics', y=1.02)
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title(f'{plot_no}. Correlation Heatmap of COVID-19 Indicators')
show_fig()
plot_no += 1
