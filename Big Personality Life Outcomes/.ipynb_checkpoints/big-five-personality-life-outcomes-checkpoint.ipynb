# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download The Big Five Personality Life Outcomes Dataset](https://www.kaggle.com/datasets/sergionefedov/big-five-personality-and-life-outcomes?select=big_five_life_outcomes.csv)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('big_five_life_outcomes.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('big_five_life_outcomes.csv')
#
# File C:\D Drive\Github\Deep-Learning\.venv\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
pd.set_option('display.max_columns', None)
df.head()

# %% [markdown]
# ## last Five row

# %%
df.tail()

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape

# %% [markdown]
# ## List out all columns

# %%
df.columns

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes

# %% [markdown]
# ## Information of all Columns

# %%
df.info()

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()

# %% [markdown]
# ## Summary

# %%
df.describe()

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(data=df, x='age', kde=True)
plt.title(f'{plot_no}. Age Distribution and Population Concentration')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(data=df, x='income_usd', kde=True)
plt.title(f'{plot_no}. Income Distribution and Earnings Concentration')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='cognitive_score', y='education_years', hue='has_degree')
plt.title(f'{plot_no}. Education Exposure and Cognitive Score by Degree Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='education_years', y='income_usd', hue='has_degree')
plt.title(f'{plot_no}. Education Years and Income Relationship by Degree Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='gpa', y='job_performance', hue='has_degree')
plt.title(f'{plot_no}. GPA and Job Performance Relationship by Degree Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='smoker', y='self_rated_health')
plt.title(f'{plot_no}. Self-Rated Health Comparison Between Smokers and Non-Smokers')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='exercise_days_week', y='life_satisfaction', hue='self_rated_health')
plt.title(f'{plot_no}. Exercise Frequency and Life Satisfaction by Self-Rated Health')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='age', y='income_usd', hue='job_performance')
plt.title(f'{plot_no}. Age and Income Relationship Across Job Performance Levels')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='parental_education_years', y='cognitive_score', hue='has_degree')
plt.title(f'{plot_no}. Parental Education and Cognitive Score by Degree Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='ever_divorced', y='life_satisfaction')
plt.title(f'{plot_no}. Life Satisfaction Comparison by Divorce History')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='partnered', y='life_satisfaction')
plt.title(f'{plot_no}. Life Satisfaction Differences by Partnership Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='job_performance', y='income_usd', hue='education_years')
plt.title(f'{plot_no}. Job Performance and Income Relationship Across Education Levels')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='self_rated_health', y='life_satisfaction', hue='exercise_days_week')
plt.title(f'{plot_no}. Health Status and Life Satisfaction Across Exercise Frequency')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='high_income', y='life_satisfaction')
plt.title(f'{plot_no}. Life Satisfaction Comparison Between High-Income and Other Groups')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(14, 8))
corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title(f'{plot_no}. Correlation Heatmap of Demographic, Education, Career, Income and Health Factors')
show_fig()
plot_no += 1

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Select important features and target

# %%
features = [
    'income_usd',
    'education_years',
    'job_performance',
    'age',
    'cognitive_score',
    'parental_ses',
    'gpa'
]

X = df[features]
y = df['high_income']

# %% [markdown]
# ## Split data into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# %% [markdown]
# ## Train Logistic Regression model

# %%
model = LogisticRegression(max_iter=1000, random_state=42)
model.fit(X_train, y_train)

# %% [markdown]
# ## Make predictions

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Calculate accuracy

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.4f}")
print(f"Model Accuracy: {accuracy * 100:.2f}%")

# %% [markdown]
# ## Plot confusion matrix

# %%
fig = plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(ax=plt.gca(), cmap='Blues')
plt.title('Logistic Regression Confusion Matrix')
plt.tight_layout()
plt.show()
