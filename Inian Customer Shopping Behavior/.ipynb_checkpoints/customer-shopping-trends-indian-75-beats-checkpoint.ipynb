# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download The Customer Shopping Behavior Dataset](https://www.kaggle.com/datasets/rewantbhriguvanshi/customer-shopping-trends-indian?select=customer_shopping_behavior-clean.csv)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('customer_shopping_behavior-clean.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#   Transaction ID Customer ID Purchase Date  Age  Gender     Location  \
# 0      TXN500000  CUST001440    2023-07-22   52   Other       Indore
# 1      TXN500001  CUST002326    2023-01-16   19  Female  Bhubaneswar
# 2      TXN500002  CUST002680    2023-01-24   40    Male    Bangalore
# 3      TXN500003  CUST001098    2024-09-06   46  Female    Ahmedabad
# 4      TXN500004  CUST003158    2023-10-18   62  Female         Pune
#
#   Online/Offline       Online Store     Category Item Purchased  Brand  Color  \
# 0        Offline  In-Store Purchase     Clothing          Jeans  Levis  Black
# 1         Online               Ajio     Clothing         Jacket   Zara   Blue
# 2         Online             Myntra     Clothing          Saree   Biba    Red
# 3        Offline  In-Store Purchase     Clothing          Jeans  Levis  White
# 4         Online           Flipkart  Accessories           Belt  Levis    Red
#
#   Size  Quantity  Purchase Amount (₹)  Discount (%) Festival/Sale  \
# ...

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#      Transaction ID Customer ID Purchase Date  Age  Gender Location  \
# 9995      TXN509995  CUST000550    2023-12-21   64    Male  Lucknow
# 9996      TXN509996  CUST003122    2024-05-17   35  Female  Lucknow
# 9997      TXN509997  CUST003322    2024-05-06   34    Male    Noida
# 9998      TXN509998  CUST000523    2023-08-22   36  Female    Patna
# 9999      TXN509999  CUST001343    2024-01-19   33  Female   Mumbai
#
#      Online/Offline       Online Store  Category Item Purchased     Brand  \
# 9995         Online             Amazon  Clothing         Shorts      Nike
# 9996        Offline  In-Store Purchase  Clothing       Trousers  Roadster
# 9997         Online             Amazon  Footwear       Sneakers    Adidas
# 9998         Online             Meesho  Footwear       Sneakers      Puma
# 9999         Online           Flipkart  Footwear          Heels      Bata
#
#       Color Size  Quantity  Purchase Amount (₹)  Discount (%) Festival/Sale  \
# ...

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (10000, 26)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Customer ID', 'Purchase Date', 'Age', 'Gender',
#        'Location', 'Online/Offline', 'Online Store', 'Category',
#        'Item Purchased', 'Brand', 'Color', 'Size', 'Quantity',
#        'Purchase Amount (₹)', 'Discount (%)', 'Festival/Sale',
#        'Shipping Charge (₹)', 'Delivery Speed', 'Delivery Time (Days)',
#        'Subscription Status', 'Payment Method', 'Review Rating',
#        'Return Status', 'Previous Purchases', 'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# Transaction ID            object
# Customer ID               object
# Purchase Date             object
# Age                        int64
# Gender                    object
# Location                  object
# Online/Offline            object
# Online Store              object
# Category                  object
# Item Purchased            object
# Brand                     object
# Color                     object
# Size                      object
# Quantity                   int64
# Purchase Amount (₹)        int64
# Discount (%)               int64
# Festival/Sale             object
# Shipping Charge (₹)        int64
# Delivery Speed            object
# Delivery Time (Days)       int64
# Subscription Status       object
# Payment Method            object
# Review Rating              int64
# Return Status             object
# Previous Purchases         int64
# Frequency of Purchases    object
# dtype: object

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Transaction ID          10000 non-null  object
#  1   Customer ID             10000 non-null  object
#  2   Purchase Date           10000 non-null  object
#  3   Age                     10000 non-null  int64
#  4   Gender                  10000 non-null  object
#  5   Location                10000 non-null  object
#  6   Online/Offline          10000 non-null  object
#  7   Online Store            10000 non-null  object
#  8   Category                10000 non-null  object
#  9   Item Purchased          10000 non-null  object
#  10  Brand                   10000 non-null  object
#  11  Color                   10000 non-null  object
#  12  Size                    10000 non-null  object
#  13  Quantity                10000 non-null  int64
# ...

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# Transaction ID            0
# Customer ID               0
# Purchase Date             0
# Age                       0
# Gender                    0
# Location                  0
# Online/Offline            0
# Online Store              0
# Category                  0
# Item Purchased            0
# Brand                     0
# Color                     0
# Size                      0
# Quantity                  0
# Purchase Amount (₹)       0
# Discount (%)              0
# Festival/Sale             0
# Shipping Charge (₹)       0
# Delivery Speed            0
# Delivery Time (Days)      0
# Subscription Status       0
# Payment Method            0
# Review Rating             0
# Return Status             0
# Previous Purchases        0
# Frequency of Purchases    0
# dtype: int64

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#                 Age      Quantity  Purchase Amount (₹)  Discount (%)  \
# count  10000.000000  10000.000000         10000.000000  10000.000000
# mean      41.095400      1.425900          6467.694500      8.704500
# std       13.537475      0.725921          8777.617508      7.278893
# min       18.000000      1.000000           107.000000      0.000000
# 25%       29.000000      1.000000          1659.000000      4.000000
# 50%       41.000000      1.000000          3491.000000      8.000000
# 75%       53.000000      2.000000          7544.250000     12.000000
# max       64.000000      4.000000        113920.000000     69.000000
#
#        Shipping Charge (₹)  Delivery Time (Days)  Review Rating  \
# count         10000.000000          10000.000000    10000.00000
# mean             20.472500              2.580500        3.47960
# std              28.954345              2.466603        0.87319
# min               0.000000              0.000000        1.00000
# ...

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['Age'], bins=20, kde=True)
plt.title(f'{plot_no}. Age Distribution of Customers')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Gender', order=df['Gender'].value_counts().index)
plt.title(f'{plot_no}. Customer Distribution by Gender')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, y='Location', order=df['Location'].value_counts().index)
plt.title(f'{plot_no}. Customer Distribution Across Locations')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Category', order=df['Category'].value_counts().index)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Product Category Purchase Frequency')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Category', y='Purchase Amount (₹)', estimator='mean', errorbar=None)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Average Purchase Amount by Product Category')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Age', y='Purchase Amount (₹)', hue='Gender')
plt.title(f'{plot_no}. Relationship Between Age and Purchase Amount')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Payment Method', order=df['Payment Method'].value_counts().index)
plt.xticks(rotation=30)
plt.title(f'{plot_no}. Preferred Payment Methods')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Return Status')
plt.title(f'{plot_no}. Product Return Status Distribution')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Return Status', y='Purchase Amount (₹)', estimator='mean', errorbar=None)
plt.title(f'{plot_no}. Average Purchase Amount by Return Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Subscription Status', y='Previous Purchases')
plt.title(f'{plot_no}. Previous Purchases by Subscription Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Frequency of Purchases', order=df['Frequency of Purchases'].value_counts().index)
plt.title(f'{plot_no}. Customer Purchase Frequency Distribution')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Frequency of Purchases', y='Purchase Amount (₹)', estimator='mean', errorbar=None)
plt.title(f'{plot_no}. Average Spending by Purchase Frequency')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Delivery Speed', y='Review Rating')
plt.title(f'{plot_no}. Customer Ratings Across Delivery Speeds')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Discount (%)', y='Purchase Amount (₹)', hue='Festival/Sale')
plt.title(f'{plot_no}. Impact of Discount on Purchase Amount')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.violinplot(data=df, x='Return Status', y='Review Rating')
plt.title(f'{plot_no}. Review Rating Distribution by Return Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Category', y='Review Rating', estimator='mean', errorbar=None)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Average Customer Rating by Product Category')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Delivery Time (Days)', y='Review Rating', hue='Return Status')
plt.title(f'{plot_no}. Delivery Time vs Customer Review Rating')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title(f'{plot_no}. Correlation Heatmap of Numerical Features')
show_fig()
plot_no += 1

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Create a copy of dataset

# %%
data = df.copy()

# %% [markdown]
# ## Remove unnecessary columns

# %%
drop_cols = ["Transaction ID", "Customer ID", "Purchase Date"]
for col in drop_cols:
    if col in data.columns:
        data.drop(columns=col, inplace=True)

# %% [markdown]
# ## Select target column

# %%
target = "Subscription Status"

# %% [markdown]
# ## Convert target into binary values

# %%
data[target] = data[target].map({"Yes": 1, "No": 0})

# %% [markdown]
# ## Remove missing target values

# %%
data = data.dropna(subset=[target])

# %% [markdown]
# ## Separate features and target

# %%
X = data.drop(columns=[target])
y = data[target]

# %% [markdown]
# ## Identify numerical and categorical columns

# %%
num_cols = X.select_dtypes(include=["int64", "float64"]).columns.tolist()
cat_cols = X.select_dtypes(include=["object"]).columns.tolist()

# %% [markdown]
# ## Create preprocessing pipeline

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            "num",
            Pipeline([
                ("imputer", SimpleImputer(strategy="median"))
            ]),
            num_cols
        ),
        (
            "cat",
            Pipeline([
                ("imputer", SimpleImputer(strategy="most_frequent")),
                ("encoder", OneHotEncoder(handle_unknown="ignore", sparse_output=False))
            ]),
            cat_cols
        )
    ]
)

# %% [markdown]
# ## Split dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %% [markdown]
# ## Create machine learning pipeline

# %%
model = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", HistGradientBoostingClassifier(
        learning_rate=0.05,
        max_depth=8,
        max_iter=400,
        min_samples_leaf=15,
        random_state=42
    ))
])

# %% [markdown]
# ## Train model

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Age', 'Quantity',
#                                                    'Purchase Amount (₹)',
#                                                    'Discount (%)',
#                                                    'Shipping Charge (₹)',
#                                                    'Delivery Time (Days)',
#                                                    'Review Rating',
#                                                    'Previous Purchases']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
# ...

# %% [markdown]
# ## Predict test data

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Calculate accuracy

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy Score: {round(accuracy * 100)}%")
# Out:
# Accuracy Score: 75%

# %% [markdown]
# ## Display confusion matrix

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, cmap="Blues")
plt.title("Confusion Matrix")
plt.show()
