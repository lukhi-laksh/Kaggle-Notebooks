# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download The Food Menu Nutrition Dataset](https://www.kaggle.com/datasets/sridipbasu/global-food-nutrition-dataset-pricing-and-rating)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('food_menu_nutrition_dataset.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
df.head()
# Out:
#                item_name item_category item_subcategory brand_name brand_tier  \
# 0             Veggie Sub      Sandwich              Veg  Five Guys        mid
# 1     Waffles with Syrup       Dessert              Veg        KFC     budget
# 2  Grilled Chicken Salad         Salad          Non-Veg   Domino's     budget
# 3     Waffles with Syrup       Dessert              Veg  Five Guys        mid
# 4      Chocolate Brownie       Dessert              Veg     Subway     budget
#
#   country     city city_tier  price_usd_normalized  serving_size_g  calories  \
# 0      UK   London     metro                  8.66           224.9     438.3
# 1     USA   Austin    tier-2                  2.78           151.7     338.5
# 2  Canada  Toronto     metro                  5.77           294.1     105.4
# 3     USA  Chicago     metro                  8.47            87.7     404.3
# 4     USA  Chicago     metro                  2.79           125.4     365.5
#
# ...

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#                   item_name item_category item_subcategory  \
# 7495              Vegan BLT      Sandwich            Vegan
# 7496          Vanilla Shake         Drink              Veg
# 7497  Crispy Chicken Burger        Burger          Non-Veg
# 7498          Vanilla Shake         Drink              Veg
# 7499         Oat Milk Latte         Drink            Vegan
#
#                      brand_name brand_tier country      city city_tier  \
# 7495                Burger King     budget   India   Chennai    tier-2
# 7496  Gordon Ramsay Bar & Grill    premium     USA     Boise    tier-3
# 7497                    Nando's        mid   India      Pune    tier-2
# 7498                  Taco Bell     budget     USA   Spokane    tier-3
# 7499                Shake Shack        mid  Canada  Edmonton    tier-2
#
#       price_usd_normalized  serving_size_g  calories  protein_g  total_fat_g  \
# 7495                  2.31           296.8     210.3       26.2         12.1
# ...

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (7500, 18)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['item_name', 'item_category', 'item_subcategory', 'brand_name',
#        'brand_tier', 'country', 'city', 'city_tier', 'price_usd_normalized',
#        'serving_size_g', 'calories', 'protein_g', 'total_fat_g',
#        'total_carbs_g', 'sodium_mg', 'sugars_g', 'avg_rating',
#        'is_bestseller'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# item_name                object
# item_category            object
# item_subcategory         object
# brand_name               object
# brand_tier               object
# country                  object
# city                     object
# city_tier                object
# price_usd_normalized    float64
# serving_size_g          float64
# calories                float64
# protein_g               float64
# total_fat_g             float64
# total_carbs_g           float64
# sodium_mg               float64
# sugars_g                float64
# avg_rating              float64
# is_bestseller             int64
# dtype: object

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   item_name             7500 non-null   object
#  1   item_category         7500 non-null   object
#  2   item_subcategory      7500 non-null   object
#  3   brand_name            7500 non-null   object
#  4   brand_tier            7500 non-null   object
#  5   country               7500 non-null   object
#  6   city                  7500 non-null   object
#  7   city_tier             7500 non-null   object
#  8   price_usd_normalized  7500 non-null   float64
#  9   serving_size_g        7500 non-null   float64
#  10  calories              7500 non-null   float64
#  11  protein_g             7500 non-null   float64
#  12  total_fat_g           7500 non-null   float64
#  13  total_carbs_g         7500 non-null   float64
# ...

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# item_name               0
# item_category           0
# item_subcategory        0
# brand_name              0
# brand_tier              0
# country                 0
# city                    0
# city_tier               0
# price_usd_normalized    0
# serving_size_g          0
# calories                0
# protein_g               0
# total_fat_g             0
# total_carbs_g           0
# sodium_mg               0
# sugars_g                0
# avg_rating              0
# is_bestseller           0
# dtype: int64

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#        price_usd_normalized  serving_size_g     calories    protein_g  \
# count           7500.000000     7500.000000  7500.000000  7500.000000
# mean               8.492565      249.692080   359.164160    11.965493
# std                8.543889      121.117787   175.298892    10.103887
# min                0.630000       50.000000     5.000000     0.000000
# 25%                3.240000      159.850000   236.550000     3.100000
# 50%                5.715000      220.500000   347.400000     9.700000
# 75%               10.050000      321.625000   480.925000    19.200000
# max               66.580000      760.200000   934.300000    45.000000
#
#        total_fat_g  total_carbs_g    sodium_mg     sugars_g   avg_rating  \
# count  7500.000000    7500.000000  7500.000000  7500.000000  7500.000000
# mean     13.933600      44.963440   511.335253    14.615618     3.816307
# std       9.926519      18.517291   345.798269    14.959637     0.589280
# ...

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['calories'], bins=30, kde=True)
plt.title(f'{plot_no}. Distribution of Calories Across Menu Items')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='brand_tier', y='price_usd_normalized', data=df)
plt.title(f'{plot_no}. Price Distribution Across Brand Tiers')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='calories', y='total_fat_g', hue='item_category', data=df)
plt.title(f'{plot_no}. Relationship Between Calories and Total Fat')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='protein_g', y='calories', hue='brand_tier', data=df)
plt.title(f'{plot_no}. High Protein Foods Versus Calorie Density')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(x='city_tier', y='avg_rating', data=df)
plt.title(f'{plot_no}. Average Food Ratings by City Tier')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(x='item_category', data=df, order=df['item_category'].value_counts().index)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Most Common Food Categories in Dataset')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='sugars_g', y='calories', hue='is_bestseller', data=df)
plt.title(f'{plot_no}. Sugar Levels Impact on Calorie Content and Bestseller Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='is_bestseller', y='avg_rating', data=df)
plt.title(f'{plot_no}. Rating Comparison Between Bestseller and Non-Bestseller Items')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.violinplot(x='item_subcategory', y='sodium_mg', data=df)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Sodium Distribution Across Food Subcategories')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='total_carbs_g', y='sugars_g', hue='item_category', data=df)
plt.title(f'{plot_no}. Carbohydrates Versus Sugar Content by Food Type')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(x='brand_name', y='calories', data=df, estimator=np.mean)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Average Calories Offered by Each Brand')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.kdeplot(data=df, x='price_usd_normalized', hue='brand_tier', fill=True)
plt.title(f'{plot_no}. Density Distribution of Food Prices by Brand Tier')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='serving_size_g', y='calories', size='total_fat_g', hue='item_category', data=df)
plt.title(f'{plot_no}. Serving Size Impact on Calories and Fat Levels')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='country', y='sodium_mg', data=df)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Country-Wise Sodium Consumption Patterns')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(x='item_category', y='protein_g', data=df, estimator=np.mean)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Average Protein Content Across Food Categories')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='price_usd_normalized', y='avg_rating', hue='brand_tier', data=df)
plt.title(f'{plot_no}. Relationship Between Product Pricing and Customer Ratings')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='item_category', y='sugars_g', data=df)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Sugar Content Comparison Across Food Categories')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.lineplot(x=df.groupby('city')['avg_rating'].mean().sort_values().index,
             y=df.groupby('city')['avg_rating'].mean().sort_values().values)
plt.xticks(rotation=90)
plt.title(f'{plot_no}. City-Wise Trend of Average Customer Ratings')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='sodium_mg', y='total_fat_g', hue='is_bestseller', data=df)
plt.title(f'{plot_no}. Sodium and Fat Combination in Bestseller Foods')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
corr = df.select_dtypes(include=np.number).corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title(f'{plot_no}. Correlation Heatmap of Nutritional and Business Features')
show_fig()
plot_no += 1
