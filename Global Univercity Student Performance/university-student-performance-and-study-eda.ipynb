# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/asifxzaman/university-students-performance-and-study-habits2026/global_university_students_performance_habits_10000.csv

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('/kaggle/input/datasets/asifxzaman/university-students-performance-and-study-habits2026/global_university_students_performance_habits_10000.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#   student_id  age  gender    country      major  university_year   GPA  \
# 0     S00001   23  Female    Germany        Law                4  3.81
# 1     S00002   26  Female        USA  Economics                2  3.46
# 2     S00003   18  Female     Canada   Medicine                3  4.00
# 3     S00004   20    Male  Australia    Physics                4  3.77
# 4     S00005   28  Female  Australia   Medicine                2  4.00
#
#    study_hours_per_day  class_attendance_percent  sleep_hours  \
# 0                  4.2                        96          6.2
# 1                  3.3                        94          6.6
# 2                  4.5                       100          6.3
# 3                  5.8                        97          7.1
# 4                  3.1                        96          8.4
#
#    screen_time_hours  social_media_hours  gaming_hours  \
# 0                3.9                 3.3           0.0
# ...

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#      student_id  age gender     country        major  university_year   GPA  \
# 9995     S09996   18   Male  Bangladesh   Psychology                1  4.00
# 9996     S09997   24   Male      Brazil   Psychology                4  2.90
# 9997     S09998   28   Male       India     Medicine                1  3.04
# 9998     S09999   23   Male          UK  Engineering                2  4.00
# 9999     S10000   27   Male       Italy   Psychology                1  3.19
#
#       study_hours_per_day  class_attendance_percent  sleep_hours  \
# 9995                  5.5                       100          7.5
# 9996                  0.5                        75          8.7
# 9997                  2.4                        91          7.5
# 9998                  4.2                       100          9.1
# 9999                  4.5                        85          5.1
#
#       screen_time_hours  social_media_hours  gaming_hours  \
# ...

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (10000, 27)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'country', 'major', 'university_year',
#        'GPA', 'study_hours_per_day', 'class_attendance_percent', 'sleep_hours',
#        'screen_time_hours', 'social_media_hours', 'gaming_hours',
#        'exercise_hours_per_week', 'part_time_job', 'relationship_status',
#        'family_income_level', 'internet_quality', 'mental_stress_level',
#        'AI_tool_usage_hours', 'favorite_AI_tool', 'note_taking_method',
#        'exam_preparation_days', 'coffee_consumption_per_day',
#        'extracurricular_hours_per_week', 'final_exam_score',
#        'assignment_score'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# student_id                         object
# age                                 int64
# gender                             object
# country                            object
# major                              object
# university_year                     int64
# GPA                               float64
# study_hours_per_day               float64
# class_attendance_percent            int64
# sleep_hours                       float64
# screen_time_hours                 float64
# social_media_hours                float64
# gaming_hours                      float64
# exercise_hours_per_week           float64
# part_time_job                      object
# relationship_status                object
# family_income_level                object
# internet_quality                   object
# mental_stress_level               float64
# AI_tool_usage_hours               float64
# favorite_AI_tool                   object
# note_taking_method                 object
# ...

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   student_id                      10000 non-null  object
#  1   age                             10000 non-null  int64
#  2   gender                          10000 non-null  object
#  3   country                         10000 non-null  object
#  4   major                           10000 non-null  object
#  5   university_year                 10000 non-null  int64
#  6   GPA                             10000 non-null  float64
#  7   study_hours_per_day             10000 non-null  float64
#  8   class_attendance_percent        10000 non-null  int64
#  9   sleep_hours                     10000 non-null  float64
#  10  screen_time_hours               10000 non-null  float64
#  11  social_media_hours              10000 non-null  float64
# ...

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# student_id                           0
# age                                  0
# gender                               0
# country                              0
# major                                0
# university_year                      0
# GPA                                  0
# study_hours_per_day                  0
# class_attendance_percent             0
# sleep_hours                          0
# screen_time_hours                    0
# social_media_hours                   0
# gaming_hours                         0
# exercise_hours_per_week              0
# part_time_job                        0
# relationship_status                  0
# family_income_level                  0
# internet_quality                     0
# mental_stress_level                  0
# AI_tool_usage_hours                  0
# favorite_AI_tool                  1720
# note_taking_method                   0
# exam_preparation_days                0
# coffee_consumption_per_day           0
# ...

# %% [markdown]
# ## Drop Favorite_AI_tool Column

# %%
df.drop(columns=['favorite_AI_tool'], inplace=True)

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#                 age  university_year           GPA  study_hours_per_day  \
# count  10000.000000     10000.000000  10000.000000          10000.00000
# mean      22.953100         2.510200      3.617585              3.50947
# std        3.159446         1.123665      0.395106              1.47435
# min       18.000000         1.000000      1.920000              0.50000
# 25%       20.000000         1.750000      3.360000              2.50000
# 50%       23.000000         3.000000      3.710000              3.50000
# 75%       26.000000         4.000000      4.000000              4.50000
# max       28.000000         4.000000      4.000000              9.40000
#
#        class_attendance_percent   sleep_hours  screen_time_hours  \
# count              10000.000000  10000.000000       10000.000000
# mean                  90.488400      7.013840           5.790490
# std                    9.952878      1.191623           1.882402
# ...

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['GPA'], kde=True)
plt.title(f'{plot_no}. Distribution of GPA Among Students')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['study_hours_per_day'], kde=True)
plt.title(f'{plot_no}. Daily Study Hours Distribution')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='study_hours_per_day', y='GPA', hue='country', data=df)
plt.title(f'{plot_no}. Relationship Between Study Hours and GPA')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='gender', y='GPA', data=df)
plt.title(f'{plot_no}. GPA Comparison Across Gender')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='sleep_hours', y='GPA', data=df)
plt.title(f'{plot_no}. Impact of Sleep Hours on GPA')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='screen_time_hours', y='GPA', data=df)
plt.title(f'{plot_no}. Screen Time vs Academic Performance')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='social_media_hours', y='mental_stress_level', data=df)
plt.title(f'{plot_no}. Social Media Usage vs Mental Stress')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='part_time_job', y='GPA', data=df)
plt.title(f'{plot_no}. Effect of Part-Time Job on GPA')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(x='relationship_status', data=df)
plt.title(f'{plot_no}. Distribution of Relationship Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='family_income_level', y='final_exam_score', data=df)
plt.title(f'{plot_no}. Family Income vs Final Exam Score')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='exercise_hours_per_week', y='mental_stress_level', data=df)
plt.title(f'{plot_no}. Exercise vs Mental Stress Level')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='AI_tool_usage_hours', y='GPA', data=df)
plt.title(f'{plot_no}. AI Tool Usage vs GPA Performance')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='note_taking_method', y='GPA', data=df)
plt.title(f'{plot_no}. Note-Taking Method Impact on GPA')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='exam_preparation_days', y='final_exam_score', data=df)
plt.title(f'{plot_no}. Exam Preparation Days vs Final Score')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='coffee_consumption_per_day', y='sleep_hours', data=df)
plt.title(f'{plot_no}. Coffee Consumption vs Sleep Hours')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='extracurricular_hours_per_week', y='GPA', data=df)
plt.title(f'{plot_no}. Extracurricular Activities vs GPA')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='class_attendance_percent', y='final_exam_score', data=df)
plt.title(f'{plot_no}. Attendance Percentage vs Final Exam Score')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(x='internet_quality', y='GPA', data=df)
plt.title(f'{plot_no}. Internet Quality vs Academic Performance')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='gaming_hours', y='GPA', data=df)
plt.title(f'{plot_no}. Gaming Hours vs GPA Performance')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(15, 8))
corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=True)
plt.title(f'{plot_no}. Correlation Heatmap of Numerical Features')
show_fig()
plot_no += 1
