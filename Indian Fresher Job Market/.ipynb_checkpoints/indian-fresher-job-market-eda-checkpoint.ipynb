# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download The Fresher Hiring Indians Dataset](https://www.kaggle.com/datasets/shambhurajejagadale/indian-fresher-job-market-who-gets-hired-and-why/data)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('fresher_hiring_india_dataset.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
df.head()
# Out:
#    candidate_id       full_name  gender  age  graduation_year  \
# 0             1  Deepika Shukla  Female   23             2021
# 1             2    Piyush Reddy    Male   25             2022
# 2             3    Itisha Arora  Female   21             2024
# 3             4     Darshan Dey    Male   22             2022
# 4             5      Uma Grewal  Female   25             2020
#
#             college     degree                  branch  cgpa  backlogs  ...  \
# 0          BITS Goa       B.E.              Electrical  5.89         3  ...
# 1     IIEST Shibpur  B.Sc (IT)  Information Technology  8.78         0  ...
# 2  BIT Mesra Ranchi        BCA   Computer Applications  6.24         3  ...
# 3          BITS Goa  B.Sc (CS)        Computer Science  8.86         3  ...
# 4   Pune University        MCA   Computer Applications  7.54         2  ...
#
#   job_location application_date         hiring_stage  interview_rounds  \
# ...

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#       candidate_id      full_name  gender  age  graduation_year  \
# 4995          4996   Bhumi Shukla  Female   20             2021
# 4996          4997   Hemant Rajan    Male   24             2023
# 4997          4998    Ojaswi More  Female   21             2020
# 4998          4999   Ojaswi Kumar  Female   23             2021
# 4999          5000  Shivam Sharma    Male   25             2020
#
#                            college     degree            branch  cgpa  \
# 4995                  IIM Calcutta  B.Sc (CS)  Computer Science  7.94
# 4996  Osmania University Hyderabad     B.Tech  Computer Science  5.56
# 4997                   NIT Calicut        BBA         Marketing  9.71
# 4998               Pune University     M.Tech              VLSI  6.84
# 4999   Jadavpur University Kolkata        MBA        Operations  7.20
#
#       backlogs  ...   job_location application_date         hiring_stage  \
# 4995         1  ...  Visakhapatnam       2023-10-15  Technical Interview
# ...

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (5000, 30)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['candidate_id', 'full_name', 'gender', 'age', 'graduation_year',
#        'college', 'degree', 'branch', 'cgpa', 'backlogs', 'gap_year',
#        'prior_internship', 'projects_count', 'certifications_count',
#        'top_skills', 'platform', 'company_applied', 'sector', 'job_role',
#        'work_type', 'job_location', 'application_date', 'hiring_stage',
#        'interview_rounds', 'response_time_days', 'offered_salary_inr',
#        'linkedin_connections', 'profile_completion_pct', 'linkedin_premium',
#        'referral_applied'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# candidate_id                int64
# full_name                  object
# gender                     object
# age                         int64
# graduation_year             int64
# college                    object
# degree                     object
# branch                     object
# cgpa                      float64
# backlogs                    int64
# gap_year                   object
# prior_internship           object
# projects_count              int64
# certifications_count        int64
# top_skills                 object
# platform                   object
# company_applied            object
# sector                     object
# job_role                   object
# work_type                  object
# job_location               object
# application_date           object
# hiring_stage               object
# interview_rounds          float64
# response_time_days          int64
# offered_salary_inr        float64
# linkedin_connections        int64
# ...

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   candidate_id            5000 non-null   int64
#  1   full_name               5000 non-null   object
#  2   gender                  5000 non-null   object
#  3   age                     5000 non-null   int64
#  4   graduation_year         5000 non-null   int64
#  5   college                 5000 non-null   object
#  6   degree                  5000 non-null   object
#  7   branch                  5000 non-null   object
#  8   cgpa                    5000 non-null   float64
#  9   backlogs                5000 non-null   int64
#  10  gap_year                5000 non-null   object
#  11  prior_internship        5000 non-null   object
#  12  projects_count          5000 non-null   int64
#  13  certifications_count    5000 non-null   int64
# ...

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# candidate_id                 0
# full_name                    0
# gender                       0
# age                          0
# graduation_year              0
# college                      0
# degree                       0
# branch                       0
# cgpa                         0
# backlogs                     0
# gap_year                     0
# prior_internship             0
# projects_count               0
# certifications_count         0
# top_skills                   0
# platform                     0
# company_applied              0
# sector                       0
# job_role                     0
# work_type                    0
# job_location                 0
# application_date             0
# hiring_stage                 0
# interview_rounds          3182
# response_time_days           0
# offered_salary_inr        4378
# linkedin_connections         0
# profile_completion_pct       0
# linkedin_premium          3901
# referral_applied             0
# ...

# %% [markdown]
# ## Drop Null Features

# %%
df.drop(columns=['interview_rounds', 'offered_salary_inr', 'linkedin_premium'], inplace=True)

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#        candidate_id          age  graduation_year         cgpa     backlogs  \
# count   5000.000000  5000.000000      5000.000000  5000.000000  5000.000000
# mean    2500.500000    23.501800      2022.491000     7.742102     1.500200
# std     1443.520003     2.293262         1.705785     1.304093     1.119397
# min        1.000000    20.000000      2020.000000     5.500000     0.000000
# 25%     1250.750000    21.000000      2021.000000     6.620000     0.000000
# 50%     2500.500000    24.000000      2022.000000     7.730000     1.000000
# 75%     3750.250000    26.000000      2024.000000     8.890000     3.000000
# max     5000.000000    27.000000      2025.000000    10.000000     3.000000
#
#        projects_count  certifications_count  response_time_days  \
# count     5000.000000            5000.00000         5000.000000
# mean         2.998000               2.49780           23.244600
# std          1.999699               1.70299           13.013418
# ...

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='hiring_stage', order=df['hiring_stage'].value_counts().index)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Hiring Stage Distribution Shows Candidate Funnel Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='gender', hue='hiring_stage')
plt.title(f'{plot_no}. Hiring Stage Comparison Across Gender Groups')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(data=df, x='age', bins=20, kde=True)
plt.title(f'{plot_no}. Candidate Age Distribution Highlights Applicant Experience Range')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='hiring_stage', y='age')
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Age Variation Across Hiring Stages')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(data=df, x='cgpa', bins=20, kde=True)
plt.title(f'{plot_no}. CGPA Distribution Shows Academic Strength of Candidates')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='hiring_stage', y='cgpa')
plt.xticks(rotation=45)
plt.title(f'{plot_no}. CGPA Comparison Across Hiring Outcomes')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='backlogs', hue='hiring_stage')
plt.title(f'{plot_no}. Backlogs Impact on Candidate Hiring Stage')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, y='college', order=df['college'].value_counts().head(10).index)
plt.title(f'{plot_no}. Top Colleges Contributing Maximum Candidates')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, y='degree', order=df['degree'].value_counts().index)
plt.title(f'{plot_no}. Degree-Wise Candidate Distribution')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, y='branch', order=df['branch'].value_counts().head(10).index)
plt.title(f'{plot_no}. Branch-Wise Candidate Demand Pattern')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, y='sector', order=df['sector'].value_counts().index)
plt.title(f'{plot_no}. Sector-Wise Hiring Application Distribution')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, y='job_role', order=df['job_role'].value_counts().head(10).index)
plt.title(f'{plot_no}. Most Applied Job Roles Among Candidates')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='work_type', hue='hiring_stage')
plt.title(f'{plot_no}. Work Type Preference Compared With Hiring Stage')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, y='job_location', order=df['job_location'].value_counts().head(10).index)
plt.title(f'{plot_no}. Top Job Locations by Candidate Applications')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='hiring_stage', y='response_time_days')
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Response Time Difference Across Hiring Stages')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='referral_applied', y='response_time_days')
plt.title(f'{plot_no}. Referral Impact on Company Response Time')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
df['application_date'] = pd.to_datetime(df['application_date'])
df.groupby(df['application_date'].dt.year).size().plot(kind='line', marker='o')
plt.title(f'{plot_no}. Year-Wise Application Trend Shows Hiring Activity Growth')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title(f'{plot_no}. Correlation Heatmap Shows Numeric Feature Relationships')
show_fig()
plot_no += 1
