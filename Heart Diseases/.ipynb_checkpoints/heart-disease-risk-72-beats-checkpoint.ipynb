# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download The Heart Disease Dataset](https://www.kaggle.com/datasets/srisyra02/synthetic-heart-disease-risk-analysis)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('heart_disease.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
df.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs restecg thalach exang  oldpeak slope  \
# 0   32    1   2       107  196.0  1.0     0.0   159.0   0.0      1.8   2.0
# 1   66    1   2       112  240.0    ?     0.0   148.0   0.0      0.7   2.0
# 2   60    0   2       123  209.0  0.0     0.0   114.0   0.0      1.1   2.0
# 3   49    0   3       105  167.0  0.0     0.0   142.0   0.0      0.1   1.0
# 4   49    1   2       114  261.0  0.0     0.0   188.0   1.0      0.1   3.0
#
#     ca thal  num
# 0  0.0    ?    0
# 1  0.0    ?    0
# 2  1.0  3.0    1
# 3  1.0  3.0    0
# 4  0.0  7.0    1

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps   chol  fbs restecg thalach exang  oldpeak slope  \
# 4995   38    0   2       128  211.0  0.0     0.0   155.0   0.0      1.6   1.0
# 4996   65    1   2       134  252.0  0.0     1.0   132.0   1.0      2.0   2.0
# 4997   68    1   4       147  254.0  0.0     1.0   152.0   0.0      2.0   2.0
# 4998   61    1   4       116  284.0  1.0     0.0   158.0   0.0      0.2     ?
# 4999   52    1   2       108  167.0  0.0     1.0   133.0   0.0      0.5   3.0
#
#        ca thal  num
# 4995  0.0  7.0    0
# 4996  0.0  7.0    1
# 4997  0.0  7.0    1
# 4998  0.0    ?    0
# 4999  0.0  7.0    1

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (5000, 14)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol         object
# fbs          object
# restecg      object
# thalach      object
# exang        object
# oldpeak     float64
# slope        object
# ca           object
# thal         object
# num           int64
# dtype: object

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       5000 non-null   int64
#  1   sex       5000 non-null   int64
#  2   cp        5000 non-null   int64
#  3   trestbps  5000 non-null   int64
#  4   chol      5000 non-null   object
#  5   fbs       5000 non-null   object
#  6   restecg   5000 non-null   object
#  7   thalach   5000 non-null   object
#  8   exang     5000 non-null   object
#  9   oldpeak   5000 non-null   float64
#  10  slope     5000 non-null   object
#  11  ca        5000 non-null   object
#  12  thal      5000 non-null   object
#  13  num       5000 non-null   int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 547.0+ KB

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps      oldpeak  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean     52.432600     0.734200     2.703800   119.929600     0.960600
# std      14.464595     0.441802     1.028337    16.476837     0.706971
# min      28.000000     0.000000     1.000000    90.000000     0.000000
# 25%      40.000000     0.000000     2.000000   108.000000     0.400000
# 50%      52.000000     1.000000     3.000000   120.000000     0.900000
# 75%      65.000000     1.000000     4.000000   131.000000     1.400000
# max      77.000000     1.000000     4.000000   178.000000     5.000000
#
#                num
# count  5000.000000
# mean      0.456200
# std       0.498128
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(data=df, x='age', hue='num', kde=True, bins=20)
plt.title(f'{plot_no}. Age Distribution by Heart Disease Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='sex', hue='num')
plt.title(f'{plot_no}. Heart Disease Prevalence by Sex')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='cp', hue='num')
plt.title(f'{plot_no}. Heart Disease Distribution Across Chest Pain Types')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='num', y='trestbps')
plt.title(f'{plot_no}. Resting Blood Pressure Differences by Heart Disease Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='age', y='trestbps', hue='num', alpha=0.7)
plt.title(f'{plot_no}. Age and Resting Blood Pressure Relationship by Heart Disease Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='num', y='oldpeak')
plt.title(f'{plot_no}. ST Depression Differences by Heart Disease Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='exang', hue='num')
plt.title(f'{plot_no}. Exercise-Induced Angina and Heart Disease Association')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='fbs', hue='num')
plt.title(f'{plot_no}. Fasting Blood Sugar Category by Heart Disease Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='restecg', hue='num')
plt.title(f'{plot_no}. Resting ECG Results Across Heart Disease Categories')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='slope', hue='num')
plt.title(f'{plot_no}. ST Segment Slope and Heart Disease Association')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='ca', hue='num')
plt.title(f'{plot_no}. Major Vessel Count and Heart Disease Distribution')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='thal', hue='num')
plt.title(f'{plot_no}. Thalassemia Category and Heart Disease Association')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.pairplot(df[['age','trestbps','chol','thalach','oldpeak','num']].dropna(), hue='num', corner=True)
plt.suptitle(f'{plot_no}. Multivariate Relationships Among Major Heart Disease Indicators', y=1.02)
plt.show()
plot_no += 1

# %%
corr = df.select_dtypes(include='number').corr()

fig = plt.figure(figsize=(12,9))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title(f'{plot_no}. Correlation Heatmap of Heart Disease Risk Factors')
show_fig()
plot_no += 1

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Separate features and target

# %%
X = df.drop('num', axis=1)
y = df['num']

# %% [markdown]
# ## Convert missing values into NaN

# %%
X = X.replace('?', pd.NA)
X = X.apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# ## Split data into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# %% [markdown]
# ## Create preprocessing and Gradient Boosting model

# %%
model = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('classifier', GradientBoostingClassifier(
        n_estimators=200,
        learning_rate=0.05,
        max_depth=3,
        subsample=0.9,
        random_state=42
    ))
])

# %% [markdown]
# ## Train the model

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('classifier',
#                  GradientBoostingClassifier(learning_rate=0.05,
#                                             n_estimators=200, random_state=42,
#                                             subsample=0.9))])

# %% [markdown]
# ## Generate predictions

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Calculate model accuracy

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2%}")
# Out:
# Model Accuracy: 71.60%

# %% [markdown]
# ## Display classification report

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.74       544
#            1       0.69      0.70      0.69       456
#
#     accuracy                           0.72      1000
#    macro avg       0.71      0.71      0.71      1000
# weighted avg       0.72      0.72      0.72      1000

# %% [markdown]
# ## Plot confusion matrix

# %%
cm = confusion_matrix(y_test, y_pred)

fig = plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - Gradient Boosting Classifier')
plt.xlabel('Predicted Class')
plt.ylabel('Actual Class')
plt.tight_layout()
plt.show()
