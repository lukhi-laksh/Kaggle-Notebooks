# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download The Student Mental Health Dataset](https://www.kaggle.com/datasets/aamir28/mindbridge-2023-student-mental-health-survey)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# /kaggle/input/datasets/aamir28/mindbridge-2023-student-mental-health-survey/student_mental_health_hybrid_learning.csv

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('student_mental_health_hybrid_learning.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
df.head()
# Out:
#   student_id  age             gender  year_of_study major_category  \
# 0    STU1001   22             Female              3       Business
# 1    STU1002   19                  M              2       Business
# 2    STU1003   23  Prefer not to say              3           STEM
# 3    STU1004   23               Male              2     Humanities
# 4    STU1005   17             Female              5           Arts
#
#    daily_sleep_hours  daily_screen_time_hours  \
# 0                6.1                      4.1
# 1                7.0                      2.3
# 2                5.0                      9.2
# 3                3.8                      2.0
# 4                5.8                      4.1
#
#    physical_activity_days_per_week  phq9_score  gad7_score  \
# 0                                1        17.0        16.0
# 1                                3         9.0         7.0
# 2                                1         1.0         2.0
# ...

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#     student_id  age  gender  year_of_study major_category  daily_sleep_hours  \
# 495    STU1496   23  Female              5            Law                5.9
# 496    STU1497   18  Female              3           STEM                5.0
# 497    STU1498   21  Female              3           STEM                5.9
# 498    STU1499   17    Male              4           STEM                5.5
# 499    STU1500   18    Male              5       Business                3.8
#
#      daily_screen_time_hours  physical_activity_days_per_week  phq9_score  \
# 495                      6.8                                2         4.0
# 496                      1.6                                3         5.0
# 497                      9.8                                0         4.0
# 498                      6.8                                2         3.0
# 499                      5.9                                4        25.0
#
# ...

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (500, 18)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'year_of_study', 'major_category',
#        'daily_sleep_hours', 'daily_screen_time_hours',
#        'physical_activity_days_per_week', 'phq9_score', 'gad7_score',
#        'perceived_stress_scale', 'weekly_study_hours',
#        'class_attendance_percent', 'online_learning_satisfaction',
#        'has_part_time_job', 'financial_stress', 'semester_type', 'cgpa'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# student_id                          object
# age                                  int64
# gender                              object
# year_of_study                        int64
# major_category                      object
# daily_sleep_hours                  float64
# daily_screen_time_hours            float64
# physical_activity_days_per_week      int64
# phq9_score                         float64
# gad7_score                         float64
# perceived_stress_scale               int64
# weekly_study_hours                 float64
# class_attendance_percent           float64
# online_learning_satisfaction       float64
# has_part_time_job                   object
# financial_stress                     int64
# semester_type                       object
# cgpa                               float64
# dtype: object

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   student_id                       500 non-null    object
#  1   age                              500 non-null    int64
#  2   gender                           500 non-null    object
#  3   year_of_study                    500 non-null    int64
#  4   major_category                   500 non-null    object
#  5   daily_sleep_hours                500 non-null    float64
#  6   daily_screen_time_hours          500 non-null    float64
#  7   physical_activity_days_per_week  500 non-null    int64
#  8   phq9_score                       486 non-null    float64
#  9   gad7_score                       486 non-null    float64
#  10  perceived_stress_scale           500 non-null    int64
#  11  weekly_study_hours               500 non-null    float64
# ...

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# student_id                          0
# age                                 0
# gender                              0
# year_of_study                       0
# major_category                      0
# daily_sleep_hours                   0
# daily_screen_time_hours             0
# physical_activity_days_per_week     0
# phq9_score                         14
# gad7_score                         14
# perceived_stress_scale              0
# weekly_study_hours                  0
# class_attendance_percent            0
# online_learning_satisfaction       24
# has_part_time_job                   0
# financial_stress                    0
# semester_type                       0
# cgpa                               12
# dtype: int64

# %% [markdown]
# ## fill missing PHQ-9 scores with median

# %%
df['phq9_score'] = df['phq9_score'].fillna(df['phq9_score'].median())

# %% [markdown]
# ## fill missing GAD-7 scores with median

# %%
df['gad7_score'] = df['gad7_score'].fillna(df['gad7_score'].median())

# %% [markdown]
# ## fill missing satisfaction values with median

# %%
df['online_learning_satisfaction'] = df['online_learning_satisfaction'].fillna(
    df['online_learning_satisfaction'].median()
)

# %% [markdown]
# ## fill missing CGPA values with median

# %%
df['cgpa'] = df['cgpa'].fillna(df['cgpa'].median())

# %% [markdown]
# ## check remaining null values

# %%
print(df.isnull().sum())
# Out:
# student_id                         0
# age                                0
# gender                             0
# year_of_study                      0
# major_category                     0
# daily_sleep_hours                  0
# daily_screen_time_hours            0
# physical_activity_days_per_week    0
# phq9_score                         0
# gad7_score                         0
# perceived_stress_scale             0
# weekly_study_hours                 0
# class_attendance_percent           0
# online_learning_satisfaction       0
# has_part_time_job                  0
# financial_stress                   0
# semester_type                      0
# cgpa                               0
# dtype: int64

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#               age  year_of_study  daily_sleep_hours  daily_screen_time_hours  \
# count  500.000000     500.000000         500.000000               500.000000
# mean    21.472000       2.662000           6.198600                 5.041200
# std      2.031125       1.280248           1.308527                 3.056375
# min     17.000000       1.000000           3.000000                 1.000000
# 25%     20.000000       2.000000           5.300000                 2.700000
# 50%     22.000000       3.000000           6.300000                 4.500000
# 75%     23.000000       4.000000           7.100000                 6.800000
# max     28.000000       5.000000          10.000000                16.000000
#
#        physical_activity_days_per_week  phq9_score  gad7_score  \
# count                       500.000000  500.000000  500.000000
# mean                          2.644000    6.414000    6.272000
# std                           1.717896    5.045147    3.948823
# ...

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(data=df, x='age', bins=10, kde=True)
plt.title(f'{plot_no}. Age Distribution of Students')
plt.xlabel('Age')
plt.ylabel('Number of Students')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(data=df, x='cgpa', bins=15, kde=True)
plt.title(f'{plot_no}. Distribution of Student CGPA')
plt.xlabel('CGPA')
plt.ylabel('Number of Students')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(data=df, x='daily_sleep_hours', bins=15, kde=True)
plt.axvline(df['daily_sleep_hours'].mean(), linestyle='--', label='Mean Sleep')
plt.title(f'{plot_no}. Distribution of Daily Sleep Hours')
plt.xlabel('Daily Sleep Hours')
plt.ylabel('Number of Students')
plt.legend()
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(data=df, x='daily_screen_time_hours', bins=15, kde=True)
plt.axvline(df['daily_screen_time_hours'].mean(), linestyle='--', label='Mean Screen Time')
plt.title(f'{plot_no}. Distribution of Daily Screen Time')
plt.xlabel('Daily Screen Time Hours')
plt.ylabel('Number of Students')
plt.legend()
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(data=df, x='phq9_score', bins=15, kde=True)
plt.title(f'{plot_no}. Distribution of PHQ-9 Depression Scores')
plt.xlabel('PHQ-9 Score')
plt.ylabel('Number of Students')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(data=df, x='gad7_score', bins=15, kde=True)
plt.title(f'{plot_no}. Distribution of GAD-7 Anxiety Scores')
plt.xlabel('GAD-7 Score')
plt.ylabel('Number of Students')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(data=df, x='perceived_stress_scale', bins=15, kde=True)
plt.title(f'{plot_no}. Distribution of Perceived Stress Levels')
plt.xlabel('Perceived Stress Scale')
plt.ylabel('Number of Students')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='year_of_study', y='cgpa')
plt.title(f'{plot_no}. CGPA Variation Across Years of Study')
plt.xlabel('Year of Study')
plt.ylabel('CGPA')
show_fig()
plot_no += 1

# %%
major_order = df.groupby('major_category')['cgpa'].median().sort_values(ascending=False).index
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='major_category', y='cgpa', order=major_order)
plt.title(f'{plot_no}. Academic Performance Comparison Across Major Categories')
plt.xlabel('Major Category')
plt.ylabel('CGPA')
plt.xticks(rotation=30)
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='daily_sleep_hours', y='cgpa', hue='perceived_stress_scale', size='weekly_study_hours', alpha=0.7)
plt.title(f'{plot_no}. Sleep Duration, Stress Level and Academic Performance')
plt.xlabel('Daily Sleep Hours')
plt.ylabel('CGPA')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.regplot(data=df, x='gad7_score', y='phq9_score', scatter_kws={'alpha':0.5}, line_kws={'linewidth':2})
plt.title(f'{plot_no}. Strong Association Between Anxiety and Depression Scores')
plt.xlabel('GAD-7 Anxiety Score')
plt.ylabel('PHQ-9 Depression Score')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='class_attendance_percent', y='cgpa', hue='year_of_study', palette='viridis', alpha=0.7)
plt.title(f'{plot_no}. Class Attendance and CGPA Across Years of Study')
plt.xlabel('Class Attendance Percentage')
plt.ylabel('CGPA')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='has_part_time_job', y='cgpa')
sns.stripplot(data=df, x='has_part_time_job', y='cgpa', alpha=0.3)
plt.title(f'{plot_no}. Academic Performance of Students With and Without Part-Time Jobs')
plt.xlabel('Has Part-Time Job')
plt.ylabel('CGPA')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='financial_stress', y='phq9_score')
plt.title(f'{plot_no}. Depression Scores Across Financial Stress Levels')
plt.xlabel('Financial Stress Level')
plt.ylabel('PHQ-9 Score')
show_fig()
plot_no += 1

# %%
mental_health_avg = df.groupby('semester_type')[['phq9_score', 'gad7_score', 'perceived_stress_scale']].mean().reset_index()
mental_health_avg = mental_health_avg.melt(id_vars='semester_type', var_name='Mental Health Measure', value_name='Average Score')
fig = plt.figure(figsize=(10,6))
sns.barplot(data=mental_health_avg, x='semester_type', y='Average Score', hue='Mental Health Measure')
plt.title(f'{plot_no}. Average Mental Health Scores by Semester Type')
plt.xlabel('Semester Type')
plt.ylabel('Average Score')
plt.legend(title='Mental Health Measure')
show_fig()
plot_no += 1

# %%
corr = df.select_dtypes(include='number').corr()
fig = plt.figure(figsize=(16,10))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title(f'{plot_no}. Correlation Heatmap of Academic, Lifestyle and Mental Health Factors')
show_fig()
plot_no += 1
