# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('student_productivity_distraction_dataset_20000.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
df.head()
# Out:
#    student_id  age  gender  study_hours_per_day  sleep_hours  \
# 0           1   23  Female                 4.35         3.63
# 1           2   20    Male                 6.14         6.58
# 2           3   29  Female                 4.98         3.26
# 3           4   27  Female                 3.19         4.58
# 4           5   24    Male                 7.67         6.21
#
#    phone_usage_hours  social_media_hours  youtube_hours  gaming_hours  \
# 0               3.38                2.73           1.83          5.26
# 1               5.48                1.51           3.13          1.73
# 2               4.83                3.63           0.18          4.71
# 3              10.06                3.95           5.75          2.52
# 4               3.02                1.59           5.46          5.65
#
#    breaks_per_day  coffee_intake_mg  exercise_minutes  assignments_completed  \
# 0               6               347               111                      2
# ...

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#        student_id  age  gender  study_hours_per_day  sleep_hours  \
# 19995       19996   26  Female                 4.81         7.83
# 19996       19997   22   Other                 0.83         4.49
# 19997       19998   25    Male                 9.36         4.33
# 19998       19999   22  Female                 0.74         4.44
# 19999       20000   19  Female                 3.64         6.35
#
#        phone_usage_hours  social_media_hours  youtube_hours  gaming_hours  \
# 19995               6.86                6.93           2.77          5.68
# 19996               6.76                3.79           2.95          1.38
# 19997               2.94                6.98           0.35          1.42
# 19998               3.15                5.99           3.11          5.01
# 19999               8.68                0.11           5.19          1.28
#
#        breaks_per_day  coffee_intake_mg  exercise_minutes  \
# 19995               6               451                 0
# ...

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (20000, 18)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day', 'sleep_hours',
#        'phone_usage_hours', 'social_media_hours', 'youtube_hours',
#        'gaming_hours', 'breaks_per_day', 'coffee_intake_mg',
#        'exercise_minutes', 'assignments_completed', 'attendance_percentage',
#        'stress_level', 'focus_score', 'final_grade', 'productivity_score'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# student_id                 int64
# age                        int64
# gender                    object
# study_hours_per_day      float64
# sleep_hours              float64
# phone_usage_hours        float64
# social_media_hours       float64
# youtube_hours            float64
# gaming_hours             float64
# breaks_per_day             int64
# coffee_intake_mg           int64
# exercise_minutes           int64
# assignments_completed      int64
# attendance_percentage    float64
# stress_level               int64
# focus_score                int64
# final_grade              float64
# productivity_score       float64
# dtype: object

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             20000 non-null  int64
#  1   age                    20000 non-null  int64
#  2   gender                 20000 non-null  object
#  3   study_hours_per_day    20000 non-null  float64
#  4   sleep_hours            20000 non-null  float64
#  5   phone_usage_hours      20000 non-null  float64
#  6   social_media_hours     20000 non-null  float64
#  7   youtube_hours          20000 non-null  float64
#  8   gaming_hours           20000 non-null  float64
#  9   breaks_per_day         20000 non-null  int64
#  10  coffee_intake_mg       20000 non-null  int64
#  11  exercise_minutes       20000 non-null  int64
#  12  assignments_completed  20000 non-null  int64
#  13  attendance_percentage  20000 non-null  float64
# ...

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# student_id               0
# age                      0
# gender                   0
# study_hours_per_day      0
# sleep_hours              0
# phone_usage_hours        0
# social_media_hours       0
# youtube_hours            0
# gaming_hours             0
# breaks_per_day           0
# coffee_intake_mg         0
# exercise_minutes         0
# assignments_completed    0
# attendance_percentage    0
# stress_level             0
# focus_score              0
# final_grade              0
# productivity_score       0
# dtype: int64

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#          student_id          age  study_hours_per_day   sleep_hours  \
# count  20000.000000  20000.00000         20000.000000  20000.000000
# mean   10000.500000     23.00745             5.254562      6.517799
# std     5773.647028      3.75489             2.742876      2.029784
# min        1.000000     17.00000             0.500000      3.000000
# 25%     5000.750000     20.00000             2.900000      4.770000
# 50%    10000.500000     23.00000             5.250000      6.510000
# 75%    15000.250000     26.00000             7.640000      8.310000
# max    20000.000000     29.00000            10.000000     10.000000
#
#        phone_usage_hours  social_media_hours  youtube_hours  gaming_hours  \
# count       20000.000000        20000.000000   20000.000000  20000.000000
# mean            6.250479            4.003655       2.990177      2.988339
# std             3.313082            2.305154       1.729815      1.732803
# ...

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['final_grade'], kde=True, bins=30)
plt.title(f'{plot_no}. Distribution of Final Grades Among Students')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='study_hours_per_day', y='final_grade', hue='gender')
plt.title(f'{plot_no}. Impact of Daily Study Hours on Final Grades by Gender')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='sleep_hours', y='productivity_score', hue='stress_level', palette='viridis')
plt.title(f'{plot_no}. Sleep Hours vs Productivity Score with Stress Level Intensity')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='gender', y='final_grade')
plt.title(f'{plot_no}. Gender-wise Comparison of Final Grade Performance')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=False, cmap='coolwarm')
plt.title(f'{plot_no}. Correlation Matrix of Academic, Lifestyle and Health Factors')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['stress_level'], kde=True, bins=20)
plt.title(f'{plot_no}. Distribution of Student Stress Levels')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='assignments_completed', y='final_grade')
plt.title(f'{plot_no}. Assignments Completion vs Final Grade Performance')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='study_hours_per_day', y='productivity_score')
plt.title(f'{plot_no}. Study Hours Per Day vs Overall Productivity Score')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='gender', y='stress_level')
plt.title(f'{plot_no}. Gender-based Comparison of Stress Levels')
show_fig()
plot_no += 1

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Encode gender column safely

# %%
df['gender'] = df['gender'].map({'Male': 0, 'Female': 1})

# %% [markdown]
# ## Define features and target

# %%
X = df.drop(columns=['student_id', 'stress_level'])
y = df['stress_level']

# %% [markdown]
# ## Split dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# ## Create pipeline with imputation + scaling + logistic regression

# %%
model = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler()),
    ('classifier', LogisticRegression(max_iter=1000))
])

# %% [markdown]
# ## Train model

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),
#                 ('scaler', StandardScaler()),
#                 ('classifier', LogisticRegression(max_iter=1000))])

# %% [markdown]
# ## Predict

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Print accuracy

# %%
print("Model Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Model Accuracy Score: 0.807

# %% [markdown]
# ## Plot confusion matrix

# %%
plt.figure(figsize=(8,6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix: Actual vs Predicted Stress Level")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()
