# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download The Student AI Adoption Prodcutivity and Mental Health Dataset](https://www.kaggle.com/datasets/shambhurajejagadale/students-ai-adoption-productivity-and-mental-health/data)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('Indian_Student_AI_Dataset.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#   student_id  age  gender    city        state branch  year_of_study  cgpa  \
# 0   STU00001   17  Female  Mumbai  West Bengal   ENTC              3  8.56
# 1   STU00002   19  Female  Nagpur        Delhi  Civil              2  8.51
# 2   STU00003   28  Female  Mumbai  Maharashtra    CSE              2  7.25
# 3   STU00004   21  Female  Nagpur  West Bengal   ENTC              2  9.24
# 4   STU00005   27  Female  Nagpur      Gujarat   ENTC              3  6.79
#
#    daily_study_hours  daily_screen_time_hours  daily_chatgpt_usage_hours  \
# 0                3.6                      4.7                        4.4
# 1                5.3                      6.7                        2.7
# 2                7.6                      4.2                        1.4
# 3                7.5                      9.3                        5.8
# 4                6.7                      3.1                        3.5
#
#    daily_coding_hours favorite_ai_tool ai_dependency_level  \
# ...

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#      student_id  age  gender     city        state      branch  year_of_study  \
# 4995   STU04996   27    Male    Delhi    Karnataka  Electrical              3
# 4996   STU04997   28  Female  Kolkata   Tamil Nadu         CSE              3
# 4997   STU04998   28    Male     Pune  Maharashtra         CSE              1
# 4998   STU04999   17    Male  Chennai   Tamil Nadu        ENTC              2
# 4999   STU05000   24    Male  Kolkata   Tamil Nadu        ENTC              2
#
#       cgpa  daily_study_hours  daily_screen_time_hours  \
# 4995  7.26                2.4                      5.2
# 4996  8.13                9.9                      9.8
# 4997  7.00                2.7                     13.4
# 4998  6.76                3.8                      3.0
# 4999  6.57                4.0                      7.7
#
#       daily_chatgpt_usage_hours  daily_coding_hours favorite_ai_tool  \
# 4995                        2.2                 5.7          ChatGPT
# ...

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (5000, 23)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'city', 'state', 'branch',
#        'year_of_study', 'cgpa', 'daily_study_hours', 'daily_screen_time_hours',
#        'daily_chatgpt_usage_hours', 'daily_coding_hours', 'favorite_ai_tool',
#        'ai_dependency_level', 'productivity_score', 'stress_level',
#        'sleep_hours', 'placement_status', 'expected_salary_lpa',
#        'internet_quality', 'preferred_programming_language',
#        'mental_wellbeing_score', 'ai_replaceability_fear'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# student_id                         object
# age                                 int64
# gender                             object
# city                               object
# state                              object
# branch                             object
# year_of_study                       int64
# cgpa                              float64
# daily_study_hours                 float64
# daily_screen_time_hours           float64
# daily_chatgpt_usage_hours         float64
# daily_coding_hours                float64
# favorite_ai_tool                   object
# ai_dependency_level                object
# productivity_score                  int64
# stress_level                        int64
# sleep_hours                       float64
# placement_status                   object
# expected_salary_lpa               float64
# internet_quality                   object
# preferred_programming_language     object
# mental_wellbeing_score              int64
# ...

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   student_id                      5000 non-null   object
#  1   age                             5000 non-null   int64
#  2   gender                          5000 non-null   object
#  3   city                            5000 non-null   object
#  4   state                           5000 non-null   object
#  5   branch                          5000 non-null   object
#  6   year_of_study                   5000 non-null   int64
#  7   cgpa                            5000 non-null   float64
#  8   daily_study_hours               5000 non-null   float64
#  9   daily_screen_time_hours         5000 non-null   float64
#  10  daily_chatgpt_usage_hours       5000 non-null   float64
#  11  daily_coding_hours              5000 non-null   float64
# ...

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# city                              0
# state                             0
# branch                            0
# year_of_study                     0
# cgpa                              0
# daily_study_hours                 0
# daily_screen_time_hours           0
# daily_chatgpt_usage_hours         0
# daily_coding_hours                0
# favorite_ai_tool                  0
# ai_dependency_level               0
# productivity_score                0
# stress_level                      0
# sleep_hours                       0
# placement_status                  0
# expected_salary_lpa               0
# internet_quality                  0
# preferred_programming_language    0
# mental_wellbeing_score            0
# ai_replaceability_fear            0
# dtype: int64

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#                age  year_of_study         cgpa  daily_study_hours  \
# count  5000.000000    5000.000000  5000.000000        5000.000000
# mean     22.454400       2.498200     7.717314           5.497760
# std       3.484071       1.116533     1.276462           2.595484
# min      17.000000       1.000000     5.500000           1.000000
# 25%      19.000000       1.000000     6.580000           3.200000
# 50%      22.000000       3.000000     7.720000           5.500000
# 75%      26.000000       3.000000     8.830000           7.800000
# max      28.000000       4.000000     9.900000          10.000000
#
#        daily_screen_time_hours  daily_chatgpt_usage_hours  daily_coding_hours  \
# count              5000.000000                5000.000000          5000.00000
# mean                  8.056500                   4.038320             4.46668
# std                   3.447777                   2.286316             2.59041
# ...

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['cgpa'], kde=True, bins=25)
plt.title(f'{plot_no}. CGPA Distribution Across Students')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['productivity_score'], kde=True, bins=25)
plt.title(f'{plot_no}. Productivity Score Distribution Among Students')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(df['mental_wellbeing_score'], kde=True, bins=25)
plt.title(f'{plot_no}. Mental Wellbeing Score Distribution')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='daily_screen_time_hours', y='stress_level', hue='gender')
plt.title(f'{plot_no}. Screen Time vs Stress Level by Gender')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='ai_dependency_level', y='productivity_score')
plt.title(f'{plot_no}. Productivity Score Across AI Dependency Levels')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='placement_status', y='cgpa')
plt.title(f'{plot_no}. CGPA Comparison Across Placement Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='placement_status', y='expected_salary_lpa')
plt.title(f'{plot_no}. Expected Salary Variation by Placement Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='branch', y='cgpa', estimator='mean', errorbar=None)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Average CGPA by Academic Branch')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='branch', y='daily_coding_hours', estimator='mean', errorbar=None)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Average Daily Coding Hours by Branch')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='preferred_programming_language', y='daily_coding_hours', estimator='mean', errorbar=None)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Coding Hours by Preferred Programming Language')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='favorite_ai_tool', order=df['favorite_ai_tool'].value_counts().index)
plt.xticks(rotation=45)
plt.title(f'{plot_no}. Most Preferred AI Tools Among Students')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='placement_status', hue='ai_dependency_level')
plt.title(f'{plot_no}. Placement Status Distribution by AI Dependency Level')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='internet_quality', y='daily_chatgpt_usage_hours', estimator='mean', errorbar=None)
plt.title(f'{plot_no}. Average ChatGPT Usage by Internet Quality')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='ai_replaceability_fear', y='stress_level', hue='ai_dependency_level')
plt.title(f'{plot_no}. AI Replaceability Fear vs Stress Level')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(15, 9))
corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title(f'{plot_no}. Correlation Heatmap of Numerical Student Performance Factors')
show_fig()
plot_no += 1
