# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download The E-Commerce Sales Dataset](https://www.kaggle.com/datasets/abdelfattahibrahim/global-e-commerce-sales-dataset-20212024)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('ecommerce_sales_dataset.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#      Order_ID  Order_Date  Year  Month Quarter  Season Customer_ID  \
# 0  ORD-000001  2023-01-18  2023      1      Q1  Winter  CUST-02791
# 1  ORD-000002  2023-11-13  2023     11      Q4    Fall  CUST-02763
# 2  ORD-000003  2022-04-28  2022      4      Q2  Spring  CUST-05729
# 3  ORD-000004  2021-10-22  2021     10      Q4    Fall  CUST-06490
# 4  ORD-000005  2023-08-06  2023      8      Q3  Summer  CUST-07594
#
#   Customer_Gender Customer_Segment         Region Country       Category  \
# 0            Male              New  North America  Mexico    Electronics
# 1          Female          Regular  North America     USA  Books & Media
# 2            Male          Regular  North America  Canada    Electronics
# 3          Female          Regular           Asia   Japan       Clothing
# 4          Female          Premium         Europe  France       Clothing
#
#    Sub_Category            Product_Name  Unit_Price  Quantity  Discount  \
# ...

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#         Order_ID  Order_Date  Year  Month Quarter  Season Customer_ID  \
# 9995  ORD-009996  2023-07-15  2023      7      Q3  Summer  CUST-01740
# 9996  ORD-009997  2022-01-01  2022      1      Q1  Winter  CUST-01137
# 9997  ORD-009998  2024-04-23  2024      4      Q2  Spring  CUST-01664
# 9998  ORD-009999  2021-09-22  2021      9      Q3    Fall  CUST-04665
# 9999  ORD-010000  2023-03-25  2023      3      Q1  Spring  CUST-05360
#
#      Customer_Gender Customer_Segment         Region Country         Category  \
# 9995          Female          Regular         Europe   Italy         Clothing
# 9996          Female          Regular           Asia   Japan  Beauty & Health
# 9997          Female          Regular           Asia   Japan    Books & Media
# 9998            Male          Regular  North America  Canada      Electronics
# 9999          Female          Regular    Middle East     UAE         Clothing
#
#       Sub_Category         Product_Name  Unit_Price  Quantity  Discount  \
# ...

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (10000, 26)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Year', 'Month', 'Quarter', 'Season',
#        'Customer_ID', 'Customer_Gender', 'Customer_Segment', 'Region',
#        'Country', 'Category', 'Sub_Category', 'Product_Name', 'Unit_Price',
#        'Quantity', 'Discount', 'Revenue', 'Cost', 'Profit', 'Profit_Margin_%',
#        'Shipping_Cost', 'Shipping_Method', 'Shipping_Days', 'Payment_Method',
#        'Order_Status'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# Order_ID             object
# Order_Date           object
# Year                  int64
# Month                 int64
# Quarter              object
# Season               object
# Customer_ID          object
# Customer_Gender      object
# Customer_Segment     object
# Region               object
# Country              object
# Category             object
# Sub_Category         object
# Product_Name         object
# Unit_Price          float64
# Quantity              int64
# Discount            float64
# Revenue             float64
# Cost                float64
# Profit              float64
# Profit_Margin_%     float64
# Shipping_Cost       float64
# Shipping_Method      object
# Shipping_Days         int64
# Payment_Method       object
# Order_Status         object
# dtype: object

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          10000 non-null  object
#  1   Order_Date        10000 non-null  object
#  2   Year              10000 non-null  int64
#  3   Month             10000 non-null  int64
#  4   Quarter           10000 non-null  object
#  5   Season            10000 non-null  object
#  6   Customer_ID       10000 non-null  object
#  7   Customer_Gender   10000 non-null  object
#  8   Customer_Segment  10000 non-null  object
#  9   Region            10000 non-null  object
#  10  Country           10000 non-null  object
#  11  Category          10000 non-null  object
#  12  Sub_Category      10000 non-null  object
#  13  Product_Name      10000 non-null  object
#  14  Unit_Price        10000 non-null  float64
#  15  Quantity          10000 non-null  int64
# ...

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Year                0
# Month               0
# Quarter             0
# Season              0
# Customer_ID         0
# Customer_Gender     0
# Customer_Segment    0
# Region              0
# Country             0
# Category            0
# Sub_Category        0
# Product_Name        0
# Unit_Price          0
# Quantity            0
# Discount            0
# Revenue             0
# Cost                0
# Profit              0
# Profit_Margin_%     0
# Shipping_Cost       0
# Shipping_Method     0
# Shipping_Days       0
# Payment_Method      0
# Order_Status        0
# dtype: int64

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#                Year         Month    Unit_Price      Quantity     Discount  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.00000
# mean    2022.756300      6.604300    236.307452      2.731300      0.17675
# std        0.878628      3.406799    380.901351      2.038508      0.16167
# min     2021.000000      1.000000     10.010000      1.000000      0.00000
# 25%     2022.000000      4.000000     42.767500      1.000000      0.00000
# 50%     2023.000000      7.000000     92.495000      2.000000      0.15000
# 75%     2023.000000     10.000000    221.822500      4.000000      0.30000
# max     2024.000000     12.000000   2497.760000     10.000000      0.50000
#
#             Revenue          Cost        Profit  Profit_Margin_%  \
# count  10000.000000  10000.000000  10000.000000     10000.000000
# mean     528.438770    384.674939    143.763831        23.648594
# std     1154.811538    828.069100    420.487992        21.496639
# ...

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(x='Region', y='Revenue', data=df)
plt.title(f'{plot_no}. Regional Revenue Comparison Shows Market Strength')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(x='Customer_Segment', data=df)
plt.title(f'{plot_no}. Customer Segment Distribution Reveals Target Audience')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='Revenue', y='Profit', hue='Category', data=df)
plt.title(f'{plot_no}. Revenue vs Profit Relationship Across Categories')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.lineplot(x='Month', y='Revenue', data=df, estimator='mean')
plt.title(f'{plot_no}. Monthly Revenue Trend Shows Seasonality Patterns')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(x='Shipping_Method', y='Shipping_Cost', data=df)
plt.title(f'{plot_no}. Shipping Cost Comparison by Method')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='Discount', y='Revenue', data=df)
plt.title(f'{plot_no}. Impact of Discount on Revenue Generation')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(x='Order_Status', data=df)
plt.title(f'{plot_no}. Order Status Distribution Indicates Fulfillment Health')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(x='Season', y='Profit', data=df)
plt.title(f'{plot_no}. Seasonal Profit Trends Reveal Peak Business Periods')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='Shipping_Days', y='Profit', data=df)
plt.title(f'{plot_no}. Shipping Time vs Profit Relationship')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.heatmap(df[['Revenue','Cost','Profit','Discount','Shipping_Cost','Shipping_Days']].corr(), annot=True)
plt.title(f'{plot_no}. Correlation Heatmap of Key Business Metrics')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(x='Category', y='Quantity', data=df)
plt.title(f'{plot_no}. Product Category vs Quantity Sold Analysis')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='Cost', y='Profit', data=df)
plt.title(f'{plot_no}. Cost vs Profit Efficiency Relationship')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.violinplot(x='Region', y='Profit_Margin_%', data=df)
plt.title(f'{plot_no}. Profit Margin Distribution Across Regions')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(x='Quarter', y='Revenue', data=df)
plt.title(f'{plot_no}. Quarterly Revenue Performance Comparison')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(x='Unit_Price', y='Quantity', data=df)
plt.title(f'{plot_no}. Price vs Quantity Sold Demand Analysis')
show_fig()
plot_no += 1
