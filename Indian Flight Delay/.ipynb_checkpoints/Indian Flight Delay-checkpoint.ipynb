# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('india_flight_delay_model_input.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
df.head()
# Out:
#   Flight_Date   Airline Flight_Number Origin_Airport Destination_Airport  \
# 0  2025-12-04    IndiGo        IN8723            BOM                 DEL
# 1  2024-01-15    IndiGo         IN558            CCU                 HYD
# 2  2023-11-06   Vistara        VI4949            HYD                 DEL
# 3  2025-08-08  SpiceJet        SP3196            BLR                 DIB
# 4  2023-09-09    IndiGo        IN8458            BLR                 JGA
#
#    Scheduled_Departure_Hour  Scheduled_Departure_Minute  Day_of_Week  Month  \
# 0                        13                          57            3     12
# 1                        19                          14            0      1
# 2                         8                          50            0     11
# 3                        11                          56            4      8
# 4                        22                          59            5      9
#
#    Is_Weekend  ...  Humidity_pct Wind_Speed_kmh  Visibility_km  Rainfall_mm  \
# 0           0  ...          46.1            4.3            9.8          5.2
# 1           0  ...          70.5            8.9           11.7          0.4
# 2           0  ...          53.7            7.8            9.6          4.3
# 3           0  ...          42.0            1.5           12.6          4.6
# 4           1  ...          58.5            1.3           11.3          3.5
#
#    Cloud_Cover_pct  Origin_Congestion_Index  Previous_Flight_Delay_Minutes  \
# 0              0.0                     63.5                              0
# 1             39.8                     95.3                              1
# 2             16.6                    100.0                              1
# 3             23.6                     51.1                              1
# 4             36.2                     67.0                              0
#
#    Turnaround_Risk_Index  Departure_Delay  Delay_Target
# 0                   23.9               43             1
# 1                   31.5               49             1
# 2                   41.5               73             1
# 3                   28.2               40             1
# 4                   27.9                0             0
#
# [5 rows x 23 columns]

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#        Flight_Date            Airline Flight_Number Origin_Airport  \
# 149995  2024-07-08             IndiGo        IN5273            BOM
# 149996  2025-03-21  Air India Express        AI8983            COK
# 149997  2023-04-11             IndiGo        IN2669            DEL
# 149998  2025-05-04          Air India        AI8266            IXR
# 149999  2024-06-17              Fly91        FL5153            MAA
#
#        Destination_Airport  Scheduled_Departure_Hour  \
# 149995                 AMD                         5
# 149996                 DEL                        11
# 149997                 CCU                         9
# 149998                 COK                         6
# 149999                 DEL                         9
#
#         Scheduled_Departure_Minute  Day_of_Week  Month  Is_Weekend  ...  \
# 149995                          49            0      7           0  ...
# 149996                          32            4      3           0  ...
# 149997                           6            1      4           0  ...
# 149998                          42            6      5           1  ...
# 149999                          20            0      6           0  ...
#
#         Humidity_pct Wind_Speed_kmh  Visibility_km  Rainfall_mm  \
# 149995          55.3           14.0           11.1          0.8
# 149996          80.3            2.3           11.2          0.0
# 149997          36.7            2.2            9.8          0.1
# 149998          53.8            3.5            8.8          3.0
# 149999          53.5           12.5            9.8          3.0
#
#         Cloud_Cover_pct  Origin_Congestion_Index  \
# 149995             25.7                     78.2
# 149996             29.1                     73.7
# 149997             32.8                     84.8
# 149998             16.6                     35.5
# 149999             25.5                     91.8
#
#         Previous_Flight_Delay_Minutes  Turnaround_Risk_Index  Departure_Delay  \
# 149995                              0                   46.1               51
# 149996                              8                   40.4               46
# 149997                              7                   40.5               50
# 149998                              0                   21.0                0
# 149999                              6                   42.8               53
#
#         Delay_Target
# 149995             1
# 149996             1
# 149997             1
# 149998             0
# 149999             1
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (150000, 23)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['Flight_Date', 'Airline', 'Flight_Number', 'Origin_Airport',
#        'Destination_Airport', 'Scheduled_Departure_Hour',
#        'Scheduled_Departure_Minute', 'Day_of_Week', 'Month', 'Is_Weekend',
#        'Peak_Hour', 'Weather', 'Temperature_C', 'Humidity_pct',
#        'Wind_Speed_kmh', 'Visibility_km', 'Rainfall_mm', 'Cloud_Cover_pct',
#        'Origin_Congestion_Index', 'Previous_Flight_Delay_Minutes',
#        'Turnaround_Risk_Index', 'Departure_Delay', 'Delay_Target'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# Flight_Date                       object
# Airline                           object
# Flight_Number                     object
# Origin_Airport                    object
# Destination_Airport               object
# Scheduled_Departure_Hour           int64
# Scheduled_Departure_Minute         int64
# Day_of_Week                        int64
# Month                              int64
# Is_Weekend                         int64
# Peak_Hour                          int64
# Weather                           object
# Temperature_C                    float64
# Humidity_pct                     float64
# Wind_Speed_kmh                   float64
# Visibility_km                    float64
# Rainfall_mm                      float64
# Cloud_Cover_pct                  float64
# Origin_Congestion_Index          float64
# Previous_Flight_Delay_Minutes      int64
# Turnaround_Risk_Index            float64
# Departure_Delay                    int64
# Delay_Target                       int64
# dtype: object

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Flight_Date                    150000 non-null  object
#  1   Airline                        150000 non-null  object
#  2   Flight_Number                  150000 non-null  object
#  3   Origin_Airport                 150000 non-null  object
#  4   Destination_Airport            150000 non-null  object
#  5   Scheduled_Departure_Hour       150000 non-null  int64
#  6   Scheduled_Departure_Minute     150000 non-null  int64
#  7   Day_of_Week                    150000 non-null  int64
#  8   Month                          150000 non-null  int64
#  9   Is_Weekend                     150000 non-null  int64
#  10  Peak_Hour                      150000 non-null  int64
#  11  Weather                        150000 non-null  object
#  12  Temperature_C                  150000 non-null  float64
#  13  Humidity_pct                   150000 non-null  float64
#  14  Wind_Speed_kmh                 150000 non-null  float64
#  15  Visibility_km                  150000 non-null  float64
#  16  Rainfall_mm                    150000 non-null  float64
#  17  Cloud_Cover_pct                150000 non-null  float64
#  18  Origin_Congestion_Index        150000 non-null  float64
#  19  Previous_Flight_Delay_Minutes  150000 non-null  int64
#  20  Turnaround_Risk_Index          150000 non-null  float64
#  21  Departure_Delay                150000 non-null  int64
#  22  Delay_Target                   150000 non-null  int64
# dtypes: float64(8), int64(9), object(6)
# memory usage: 26.3+ MB

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# Flight_Date                      0
# Airline                          0
# Flight_Number                    0
# Origin_Airport                   0
# Destination_Airport              0
# Scheduled_Departure_Hour         0
# Scheduled_Departure_Minute       0
# Day_of_Week                      0
# Month                            0
# Is_Weekend                       0
# Peak_Hour                        0
# Weather                          0
# Temperature_C                    0
# Humidity_pct                     0
# Wind_Speed_kmh                   0
# Visibility_km                    0
# Rainfall_mm                      0
# Cloud_Cover_pct                  0
# Origin_Congestion_Index          0
# Previous_Flight_Delay_Minutes    0
# Turnaround_Risk_Index            0
# Departure_Delay                  0
# Delay_Target                     0
# dtype: int64

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#        Scheduled_Departure_Hour  Scheduled_Departure_Minute    Day_of_Week  \
# count             150000.000000               150000.000000  150000.000000
# mean                  14.001260                   29.533773       2.997107
# std                    5.480291                   17.322034       2.003977
# min                    5.000000                    0.000000       0.000000
# 25%                    9.000000                   15.000000       1.000000
# 50%                   14.000000                   30.000000       3.000000
# 75%                   19.000000                   45.000000       5.000000
# max                   23.000000                   59.000000       6.000000
#
#                Month     Is_Weekend     Peak_Hour  Temperature_C  \
# count  150000.000000  150000.000000  150000.00000  150000.000000
# mean        6.512973       0.286820       0.47528      27.028051
# std         3.445167       0.452278       0.49939       5.489234
# min         1.000000       0.000000       0.00000      10.000000
# 25%         4.000000       0.000000       0.00000      22.900000
# 50%         7.000000       0.000000       0.00000      27.000000
# 75%        10.000000       1.000000       1.00000      31.100000
# max        12.000000       1.000000       1.00000      45.000000
#
#         Humidity_pct  Wind_Speed_kmh  Visibility_km    Rainfall_mm  \
# count  150000.000000   150000.000000  150000.000000  150000.000000
# mean       56.332991        5.993765      10.891581       1.666205
# std        10.161597        4.223185       1.271557       2.409718
# min        20.000000        0.000000       5.100000       0.000000
# 25%        49.500000        2.900000      10.000000       0.000000
# 50%        56.300000        5.000000      10.900000       0.600000
# 75%        63.200000        8.100000      11.700000       2.500000
# max       100.000000       35.000000      15.000000      30.400000
#
#        Cloud_Cover_pct  Origin_Congestion_Index  \
# count    150000.000000            150000.000000
# mean         25.013692                72.406212
# std          13.020552                19.277706
# min           0.000000                 0.000000
# 25%          15.800000                60.900000
# 50%          24.800000                72.700000
# 75%          33.800000                88.800000
# max          90.100000               100.000000
#
#        Previous_Flight_Delay_Minutes  Turnaround_Risk_Index  Departure_Delay  \
# count                  150000.000000          150000.000000    150000.000000
# mean                        6.170807              35.715187        42.664340
# std                         6.483483               8.719541        19.016712
# min                         0.000000               0.400000         0.000000
# 25%                         1.000000              29.900000        39.000000
# 50%                         4.000000              35.700000        47.000000
# 75%                         9.000000              41.500000        54.000000
# max                        71.000000              88.200000       119.000000
#
#         Delay_Target
# count  150000.000000
# mean        0.866167
# std         0.340474
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %% [markdown]
# # EDA

# %%
def show_fig():
    plt.tight_layout()
    plt.show()

plot_no = 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Airline', hue='Delay_Target')
plt.title(f'{plot_no}. Flight Delay Patterns Across Airlines')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.histplot(data=df, x='Departure_Delay', bins=30, kde=True)
plt.title(f'{plot_no}. Distribution of Departure Delay Minutes')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Delay_Target', y='Departure_Delay')
plt.title(f'{plot_no}. Departure Delay Distribution by Delay Target')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Day_of_Week', y='Departure_Delay', errorbar=None)
plt.title(f'{plot_no}. Average Departure Delay Across Days of the Week')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Month', y='Departure_Delay', errorbar=None)
plt.title(f'{plot_no}. Monthly Variation in Average Departure Delay')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Is_Weekend', hue='Delay_Target')
plt.title(f'{plot_no}. Weekend Effect on Flight Delay Risk')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Previous_Flight_Delay_Minutes', y='Departure_Delay', hue='Delay_Target', alpha=0.6)
plt.title(f'{plot_no}. Previous Flight Delays as a Predictor of Departure Delay')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Turnaround_Risk_Index', y='Departure_Delay', hue='Delay_Target', alpha=0.6)
plt.title(f'{plot_no}. Turnaround Risk and Its Relationship with Departure Delay')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Delay_Target', y='Turnaround_Risk_Index')
plt.title(f'{plot_no}. Turnaround Risk Levels for Delayed and On-Time Flights')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Origin_Congestion_Index', y='Departure_Delay', hue='Delay_Target', alpha=0.6)
plt.title(f'{plot_no}. Origin Airport Congestion Versus Departure Delay')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Delay_Target', y='Origin_Congestion_Index')
plt.title(f'{plot_no}. Airport Congestion Levels by Flight Delay Status')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Humidity_pct', y='Departure_Delay', hue='Delay_Target', alpha=0.6)
plt.title(f'{plot_no}. Humidity and Its Association with Departure Delay')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Wind_Speed_kmh', y='Departure_Delay', hue='Delay_Target', alpha=0.6)
plt.title(f'{plot_no}. Wind Speed Versus Departure Delay')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Visibility_km', y='Departure_Delay', hue='Delay_Target', alpha=0.6)
plt.title(f'{plot_no}. Visibility Conditions and Departure Delay')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Rainfall_mm', y='Departure_Delay', hue='Delay_Target', alpha=0.6)
plt.title(f'{plot_no}. Rainfall Intensity and Departure Delay')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Cloud_Cover_pct', y='Departure_Delay', hue='Delay_Target', alpha=0.6)
plt.title(f'{plot_no}. Cloud Cover and Its Relationship with Departure Delay')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Scheduled_Departure_Hour', y='Departure_Delay', hue='Delay_Target', errorbar=None)
plt.title(f'{plot_no}. Departure Delay Risk Across Scheduled Departure Hours')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Delay_Target')
plt.title(f'{plot_no}. Class Distribution of Flight Delay Target')
show_fig()
plot_no += 1

# %%
fig = plt.figure(figsize=(14,10))
corr = df.select_dtypes(include='number').corr()
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title(f'{plot_no}. Correlation Heatmap of Flight Delay and Operational Factors')
show_fig()
plot_no += 1

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Select features and target

# %%
X = df.drop(columns=['Delay_Target', 'Departure_Delay', 'Flight_Date'], errors='ignore')
y = df['Delay_Target']

# %% [markdown]
# ## Identify numerical and categorical features

# %%
numerical_features = X.select_dtypes(include=['number']).columns
categorical_features = X.select_dtypes(include=['object', 'category']).columns

# %% [markdown]
# ## Preprocess features with memory-efficient encoding

# %%
preprocessor = ColumnTransformer([
    ('num', Pipeline([
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ]), numerical_features),
    
    ('cat', Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
    ]), categorical_features)
])

# %% [markdown]
# ## Create a fast supervised model

# %%
model = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(
        max_iter=300,
        C=1.0,
        solver='lbfgs',
        random_state=42
    ))
])

# %% [markdown]
# ## Split the dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %% [markdown]
# ## Train the model

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['Scheduled_Departure_Hour', 'Scheduled_Departure_Minute', 'Day_of_Week',
#        'Month', 'Is_Weekend', 'Peak_Hour', 'Temperature_C', 'Humidity_pct',
#        'Wind_Speed_kmh', 'Visibility_km', 'Rainfall_mm',...
#        'Turnaround_Risk_Index'],
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   Index(['Airline', 'Flight_Number', 'Origin_Airport', 'Destination_Airport',
#        'Weather'],
#       dtype='object'))])),
#                 ('classifier',
#                  LogisticRegression(max_iter=300, random_state=42))])

# %% [markdown]
# ## Generate predictions

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Print model accuracy

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2%}")
# Out:
# Model Accuracy: 93.85%

# %% [markdown]
# ## Display confusion matrix

# %%
fig = plt.figure(figsize=(8, 5))
ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred,
    values_format='d',
    cmap='Blues'
)
plt.title('Confusion Matrix - Flight Delay Prediction')
show_fig()
