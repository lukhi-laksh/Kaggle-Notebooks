# %% [markdown]
# # 📊 Dataset Information
#
# **Note:** The dataset for this project is **not included in this repository** to keep the repository lightweight.
#
# You can download the dataset from **Kaggle** using the link below:
#
# [Download The Churn Modelling Dataset](https://www.kaggle.com/datasets/rjmanoj/credit-card-customer-churn-prediction/data)
#
# Please make sure to place the downloaded CSV file in the same directory as this notebook before running any code.

# %% [markdown]
# # Importing

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## Import CSV And convert to DataFrame

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Frist five row

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# ## last Five row

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %% [markdown]
# ## Shape of our dataset

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# ## List out all columns

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %% [markdown]
# ## Datatype of each columns

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# ## Information of all Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Check Null Value

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ## Drop Unusefull Features

# %%
df.drop(columns=['RowNumber', 'CustomerId', 'Surname'], inplace=True)

# %% [markdown]
# ## Check Dupicate Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Check Categorical Features

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %% [markdown]
# ## Summary

# %%
df.describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288       1.530200
# std       96.653299     10.487806      2.892174   62397.405202       0.581654
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97198.540000       1.000000
# 75%      718.000000     44.000000      7.000000  127644.240000       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000    10000.000000     10000.000000  10000.000000
# mean       0.70550        0.515100    100090.239881      0.203700
# std        0.45584        0.499797     57510.492818      0.402769
# min        0.00000        0.000000        11.580000      0.000000
# 25%        0.00000        0.000000     51002.110000      0.000000
# 50%        1.00000        1.000000    100193.915000      0.000000
# 75%        1.00000        1.000000    149388.247500      0.000000
# max        1.00000        1.000000    199992.480000      1.000000

# %% [markdown]
# ## One Hot Encoding

# %%
df = pd.get_dummies(df, columns=['Geography', 'Gender'], drop_first=True)

# %%
X = df.drop(columns=['Exited'])
y = df['Exited']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Train Model

# %% [markdown]
# ## Model Architecture

# %%
model = Sequential()

model.add(Dense(11, activation='relu', input_dim = 11))
model.add(Dense(11, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ## Summary of model

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 11)                  │             132 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 11)                  │             132 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              12 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 276 (1.08 KB)
#  Trainable params: 276 (1.08 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Set Loss and Optimizer

# %%
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ## Train Model

# %%
history = model.fit(X_train_scaled, y_train, epochs=20, validation_split=0.2)
# Out:
# Epoch 1/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7509 - loss: 0.5508 - val_accuracy: 0.8056 - val_loss: 0.4918
# Epoch 2/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8069 - loss: 0.4531 - val_accuracy: 0.8094 - val_loss: 0.4481
# Epoch 3/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8141 - loss: 0.4315 - val_accuracy: 0.8138 - val_loss: 0.4350
# Epoch 4/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8200 - loss: 0.4229 - val_accuracy: 0.8144 - val_loss: 0.4277
# Epoch 5/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8256 - loss: 0.4168 - val_accuracy: 0.8175 - val_loss: 0.4224
# Epoch 6/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8306 - loss: 0.4104 - val_accuracy: 0.8213 - val_loss: 0.4141
# Epoch 7/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8336 - loss: 0.4032 - val_accuracy: 0.8263 - val_loss: 0.4073
# Epoch 8/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8377 - loss: 0.3948 - val_accuracy: 0.8325 - val_loss: 0.3969
# Epoch 9/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8441 - loss: 0.3821 - val_accuracy: 0.8406 - val_loss: 0.3830
# Epoch 10/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8522 - loss: 0.3689 - val_accuracy: 0.8487 - val_loss: 0.3695
# Epoch 11/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8552 - loss: 0.3585 - val_accuracy: 0.8500 - val_loss: 0.3612
# Epoch 12/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8595 - loss: 0.3512 - val_accuracy: 0.8512 - val_loss: 0.3571
# Epoch 13/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8603 - loss: 0.3467 - val_accuracy: 0.8512 - val_loss: 0.3532
# Epoch 14/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8606 - loss: 0.3436 - val_accuracy: 0.8525 - val_loss: 0.3507
# Epoch 15/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8620 - loss: 0.3414 - val_accuracy: 0.8531 - val_loss: 0.3501
# Epoch 16/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8627 - loss: 0.3393 - val_accuracy: 0.8537 - val_loss: 0.3478
# Epoch 17/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8620 - loss: 0.3383 - val_accuracy: 0.8550 - val_loss: 0.3459
# Epoch 18/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8625 - loss: 0.3368 - val_accuracy: 0.8519 - val_loss: 0.3481
# Epoch 19/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8623 - loss: 0.3361 - val_accuracy: 0.8544 - val_loss: 0.3441
# Epoch 20/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8603 - loss: 0.3351 - val_accuracy: 0.8519 - val_loss: 0.3443

# %% [markdown]
# ## Check Weights

# %%
model.layers[0].get_weights()[1]
# Out:
# array([ 0.51809573, -0.14342242,  0.80471355,  0.42255458, -0.3786594 ,
#         0.2135494 , -0.12350042,  0.24514021,  0.41813254, -0.01606574,
#         0.19987068], dtype=float32)

# %%
model.layers[1].get_weights()[1]
# Out:
# array([-0.23040436, -0.13067181, -0.14565085, -0.15962476,  0.49066824,
#         0.38129503,  0.35553825,  0.18452425,  0.0835264 , -0.15251835,
#        -0.16701435], dtype=float32)

# %% [markdown]
# ## Test Model

# %%
y_log = model.predict(X_test_scaled)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ## Decision Threshold

# %%
y_pred = np.where(y_log>0.5, 1, 0)

# %% [markdown]
# ## Check Accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.857

# %% [markdown]
# ## Accuracy and Loss Epoch Charts

# %%
history.history
# Out:
# {'accuracy': [0.7509375214576721,
#   0.8068749904632568,
#   0.8140624761581421,
#   0.8199999928474426,
#   0.8256250023841858,
#   0.8306249976158142,
#   0.8335937261581421,
#   0.8376562595367432,
#   0.8440625071525574,
#   0.8521875143051147,
#   0.8551562428474426,
#   0.8595312237739563,
#   0.8603125214576721,
#   0.8606250286102295,
#   0.8620312213897705,
#   0.8626562356948853,
#   0.8620312213897705,
#   0.862500011920929,
#   0.8623437285423279,
#   0.8603125214576721],
#  'loss': [0.5508020520210266,
#   0.4531337022781372,
#   0.43150877952575684,
#   0.42287102341651917,
#   0.4167812764644623,
#   0.4103533923625946,
#   0.40324071049690247,
#   0.39480385184288025,
#   0.3821013271808624,
#   0.36894840002059937,
#   0.35851427912712097,
#   0.35122689604759216,
#   0.3467485010623932,
#   0.34358474612236023,
#   0.341373473405838,
#   0.33934715390205383,
#   0.33825743198394775,
#   0.336822509765625,
#   0.3361198306083679,
#   0.335061252117157],
#  'val_accuracy': [0.8056250214576721,
#   0.809374988079071,
#   0.8137500286102295,
#   0.8143749833106995,
#   0.8174999952316284,
#   0.8212500214576721,
#   0.8262500166893005,
#   0.8324999809265137,
#   0.840624988079071,
#   0.8487499952316284,
#   0.8500000238418579,
#   0.8512499928474426,
#   0.8512499928474426,
#   0.8525000214576721,
#   0.8531249761581421,
#   0.8537499904632568,
#   0.8550000190734863,
#   0.8518750071525574,
#   0.8543750047683716,
#   0.8518750071525574],
#  'val_loss': [0.4917665123939514,
#   0.4481339752674103,
#   0.4350144863128662,
#   0.4277154505252838,
#   0.42240387201309204,
#   0.41408875584602356,
#   0.4072599709033966,
#   0.39691683650016785,
#   0.383004754781723,
#   0.3695122003555298,
#   0.36117005348205566,
#   0.35708799958229065,
#   0.35317257046699524,
#   0.3506816625595093,
#   0.35013100504875183,
#   0.34782469272613525,
#   0.3459278345108032,
#   0.34807875752449036,
#   0.34405314922332764,
#   0.3443070352077484]}

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
